# %%
# %run test.py
# Out:
# *************************************************************************
# *************************************************************************
# *************************************************************************
# *************************************************************************
# *************************************************************************
# Model: Linear + ReLU + Linear +ReLU + Linear + ReLU + Linear + Tanh
# Loss: MSE
# Optimizer: SGD
# *************************************************************************
# Training
# *************************************************************************
# Epoch: 1/50.. Training Loss: 1.0156.. Training Accuracy: 0.4980.. Validation/Test Loss: 1.0031.. Validation/Test Accuracy: 0.5240..
# Epoch: 2/50.. Training Loss: 0.9901.. Training Accuracy: 0.5720.. Validation/Test Loss: 0.9776.. Validation/Test Accuracy: 0.5780..
# ...
