# %% [markdown]
# # Miniproject-1

# %% [markdown]
# Note: In this analysis notebook, we use numpy to save the history of training loss and accuracy of each model for convenience of visualization.
#
# However, in our test section, we only use torch as demanded in the description.

# %% [markdown]
# # 1. Loading and Preparing Data

# %%
import torch
import math
from torch import optim
from torch import Tensor
from torch.autograd import Variable
from torch import nn
from torch.nn import functional as F
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
import dlc_practical_prologue as prologue
#train_input, train_target, train_classes, test_input, test_target, test_classes= prologue.generate_pair_sets(1000)
train_input,train_target,train_class,test_input,test_target,test_class=prologue.generate_pair_sets(1000)
train_mean, train_std = train_input.mean(), train_input.std()
train_input.sub_(train_mean).div_(train_std)
test_input.sub_(train_mean).div_(train_std)
print('train_input', train_input.size(), 'train_target', train_target.size(),'train_class', train_class.size())
print('test_input', test_input.size(), 'test_target', test_target.size(),'test_class', test_class.size())
# Out:
# train_input torch.Size([1000, 2, 14, 14]) train_target torch.Size([1000]) train_class torch.Size([1000, 2])
# test_input torch.Size([1000, 2, 14, 14]) test_target torch.Size([1000]) test_class torch.Size([1000, 2])

# %% [markdown]
# # 2. Preparing Auxiliary Function

# %%
def evaluate_result(train_loss_list,train_accuracy_list, test_loss_list,test_accuracy_list, title):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.suptitle(title)
    ax1.set_yscale('log')
    ax1.plot(train_loss_list, label = "training loss")
    ax1.plot(test_loss_list, label = "validation loss")
    ax1.set_ylabel('categorical cross entropy')
    ax1.set_xlabel('epoch')
    ax1.legend()
    ax2.plot(train_accuracy_list, label = "training accuracy")
    ax2.plot(test_accuracy_list, label = "validation accuracy")
    ax2.set_ylabel('classification accuracy')
    ax2.set_xlabel('epoch')
    ax2.legend()
    print("The Best Validation Accuracy is : {:.4f}..".format(max(test_accuracy_list)))

# %%
def plot_different_histories(train_loss_list_1,train_accuracy_list_1, test_loss_list_1,test_accuracy_list_1,
                             train_loss_list_2,train_accuracy_list_2, test_loss_list_2,test_accuracy_list_2,
                             train_loss_list_3,train_accuracy_list_3, test_loss_list_3,test_accuracy_list_3,
                             train_loss_list_4,train_accuracy_list_4, test_loss_list_4,test_accuracy_list_4,
                             train_loss_list_5=None,train_accuracy_list_5=None, test_loss_list_5=None,test_accuracy_list_5=None,
                             label_1='', label_2='', label_3='', label_4='', label_5='',title=''):
    
    if train_loss_list_1==None:
        fig, ax = plt.subplots(1,1,figsize=(10, 6))
        fig.suptitle(title)
        ax.plot(train_accuracy_list_1, label = label_1+" training accuracy",c='r')
        ax.plot(test_accuracy_list_1, label =label_1+ " validation accuracy",c='r',linestyle='--')
        ax.plot(train_accuracy_list_2, label = label_2+" training accuracy",c='g')
        ax.plot(test_accuracy_list_2, label =label_2+ " validation accuracy",c='g',linestyle='--')
        ax.plot(train_accuracy_list_3, label = label_3+" training accuracy",c='b')
        ax.plot(test_accuracy_list_3, label =label_3+ " validation accuracy",c='b',linestyle='--')
        ax.plot(train_accuracy_list_4, label = label_4+" training accuracy",c='y')
        ax.plot(test_accuracy_list_4, label =label_4+ " validation accuracy",c='y',linestyle='--')
        ax.set_ylabel('boolean classification accuracy')
        ax.set_xlabel('epoch')
        ax.legend()
        return
    
    fig, (ax1, ax2) = plt.subplots(1,2,figsize=(15, 7))
    fig.suptitle(title)
    ax1.set_yscale('log')                    
    if train_loss_list_5==None:
        ax1.set_yscale('log')
        ax1.plot(train_loss_list_1, label = label_1+" training loss",c='r')
        ax1.plot(test_loss_list_1, label = label_1+" validation loss",c='r',linestyle='--')
        ax1.plot(train_loss_list_2, label = label_2+" training loss",c='g')
        ax1.plot(test_loss_list_2, label = label_2+" validation loss",c='g',linestyle='--')
        ax1.plot(train_loss_list_3, label = label_3+" training loss",c='b')
        ax1.plot(test_loss_list_3, label = label_3+" validation loss",c='b',linestyle='--')
        ax1.plot(train_loss_list_4, label = label_4+" training loss",c='y')
        ax1.plot(test_loss_list_4, label = label_4+" validation loss",c='y',linestyle='--')
        ax1.set_ylabel('categorical cross entropy')
        ax1.set_xlabel('epoch')
        ax1.legend()
        ax2.plot(train_accuracy_list_1, label = label_1+" training accuracy",c='r')
        ax2.plot(test_accuracy_list_1, label =label_1+ " validation accuracy",c='r',linestyle='--')
        ax2.plot(train_accuracy_list_2, label = label_2+" training accuracy",c='g')
        ax2.plot(test_accuracy_list_2, label =label_2+ " validation accuracy",c='g',linestyle='--')
        ax2.plot(train_accuracy_list_3, label = label_3+" training accuracy",c='b')
        ax2.plot(test_accuracy_list_3, label =label_3+ " validation accuracy",c='b',linestyle='--')
        ax2.plot(train_accuracy_list_4, label = label_4+" training accuracy",c='y')
        ax2.plot(test_accuracy_list_4, label =label_4+ " validation accuracy",c='y',linestyle='--')
        ax2.set_ylabel('classification accuracy')
        ax2.set_xlabel('epoch')
        ax2.legend()
        
    else:
        ax1.set_yscale('log')
        ax1.plot(train_loss_list_1, label = label_1+" training loss",c='r')
        ax1.plot(test_loss_list_1, label = label_1+" validation loss",c='r',linestyle='--')
        ax1.plot(train_loss_list_2, label = label_2+" training loss",c='g')
        ax1.plot(test_loss_list_2, label = label_2+" validation loss",c='g',linestyle='--')
        ax1.plot(train_loss_list_3, label = label_3+" training loss",c='b')
        ax1.plot(test_loss_list_3, label = label_3+" validation loss",c='b',linestyle='--')
        ax1.plot(train_loss_list_4, label = label_4+" training loss",c='y')
        ax1.plot(test_loss_list_4, label = label_4+" validation loss",c='y',linestyle='--')
        ax1.plot(train_loss_list_5, label = label_5+" training loss",c='brown')
        ax1.plot(test_loss_list_5, label = label_5+" validation loss",c='brown',linestyle='--')
        ax1.set_ylabel('categorical cross entropy')
        ax1.set_xlabel('epoch')
        ax1.legend()
        ax2.plot(train_accuracy_list_1, label = label_1+" training accuracy",c='r')
        ax2.plot(test_accuracy_list_1, label =label_1+ " validation accuracy",c='r',linestyle='--')
        ax2.plot(train_accuracy_list_2, label = label_2+" training accuracy",c='g')
        ax2.plot(test_accuracy_list_2, label =label_2+ " validation accuracy",c='g',linestyle='--')
        ax2.plot(train_accuracy_list_3, label = label_3+" training accuracy",c='b')
        ax2.plot(test_accuracy_list_3, label =label_3+ " validation accuracy",c='b',linestyle='--')
        ax2.plot(train_accuracy_list_4, label = label_4+" training accuracy",c='y')
        ax2.plot(test_accuracy_list_4, label =label_4+ " validation accuracy",c='y',linestyle='--')
        ax2.plot(train_accuracy_list_5, label = label_5+" training accuracy",c='brown')
        ax2.plot(test_accuracy_list_5, label =label_5+ " validation accuracy",c='brown',linestyle='--')
        ax2.set_ylabel('classification accuracy')
        ax2.set_xlabel('epoch')
        ax2.legend()

# %%
def train_model(model , optim='sgd',
                train_input=train_input, train_target=train_target, 
                test_input=test_input, test_target=test_target,
                epochs=50, batch_size=100, learning_rate=1e-3, momentum=0,
                 if_print=False):
    criterion = nn.CrossEntropyLoss()
    if optim=='sgd':
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=momentum)
    elif optim=='adm':
        optimizer = torch.optim.ADAM(model.parameters(),lr=learning_rate)
    train_loss_list=train_accuracy_list=[]
    valid_loss_list=valid_accuracy_list=[]
    test_loss_list=test_accuracy_list=[]
    for e in range(epochs):
        for b in range(0, train_input.size(0), batch_size):
            temp_train_input=train_input.narrow(0, b, batch_size)    
            temp_train_target=train_target.narrow(0, b, batch_size)
            train_output = model(temp_train_input)
            loss = criterion(train_output, temp_train_target)
            model.zero_grad()
            loss.backward()
            optimizer.step()
                
        train_temp_output = model(train_input)
        train_temp_loss = criterion(train_temp_output, train_target)
        _, temp_train_pred =torch.max(F.softmax(train_temp_output).data, 1)
        train_temp_accuracy=((temp_train_pred == train_target).sum().item())/train_input.size(0)
        
        test_temp_output=model(test_input)
        test_temp_loss = criterion(test_temp_output, test_target)
        _, temp_test_pred =torch.max(F.softmax(test_temp_output).data, 1)
        test_temp_accuracy=((temp_test_pred == test_target).sum().item())/test_input.size(0)
        
        train_loss_list=train_loss_list+[train_temp_loss]
        train_accuracy_list=train_accuracy_list+[train_temp_accuracy]
        test_loss_list=test_loss_list+[test_temp_loss]
        test_accuracy_list=test_accuracy_list+[test_temp_accuracy]
        
        if if_print:
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Training Loss: {:.4f}..".format(train_temp_loss),
                  "Training Accuracy: {:.4f}..".format(train_temp_accuracy), 
                  "Validation Loss: {:.4f}..".format(test_temp_loss),
                  "Validation Accuracy: {:.4f}..".format(test_temp_accuracy),  )
                

    return model, train_loss_list,train_accuracy_list, test_loss_list,test_accuracy_list

# %%
def weights_init(m):
    if isinstance(m, nn.Conv1d) or isinstance(m,nn.Linear):
        m.weight.data.normal_(0.0, 0.05)
        m.bias.data.fill_(0)

# %%
import random
def data_init(train_input,train_target, train_class, num=1000):
    index=[i for i in range(num)]
    random.shuffle(index)
    new_train_input=train_input[index,:,:,:]
    new_train_target=train_target[index]
    new_train_class=train_class[index,:]
    
    return new_train_input,new_train_target,  new_train_class

train_input, train_target, train_class = data_init(train_input,train_target, train_class, num=1000)

# %% [markdown]
# # 3. MLP

# %%
class MLP(nn.Module):
    def __init__(self,nb_layer=1,nb_hidden_neuron=50):
        super(MLP, self).__init__()
        self.fc_begin = nn.Linear(392 ,nb_hidden_neuron)
        self.fc_hidden=nn.Linear(nb_hidden_neuron ,nb_hidden_neuron)
        self.fc_last = nn.Linear(nb_hidden_neuron, 2)
        
        self.fc_one_layer=nn.Linear(392 ,2)
        self.nb_layer=nb_layer

    def forward(self, x):
        x=x.view(x.size(0),-1)
        if self.nb_layer==1:
            x=self.fc_one_layer(x)
        else:
            x = F.relu(self.fc_begin(x))
            for i in range(self.nb_layer-2):
                x = F.relu(self.fc_hidden(x))
            x = self.fc_last(x)
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %% [markdown]
# ### 3.1 1-layer MLP

# %%
model_mlp1=MLP(nb_layer=1,nb_hidden_neuron=100)
model_mlp1.apply(weights_init)
model_mlp1,train_loss_mlp1,train_accuracy_mlp1, test_loss_mlp1,test_accuracy_mlp1=train_model(model_mlp1,if_print=True, learning_rate=0.01)
evaluate_result(train_loss_mlp1,train_accuracy_mlp1, test_loss_mlp1,test_accuracy_mlp1, 'Learning Curve of 1-layer MLP')
# Out:
# Epoch: 1/50.. Training Loss: 1133.8541.. Training Accuracy: 0.5640.. Validation Loss: 1109.3867.. Validation Accuracy: 0.5710..
# Epoch: 2/50.. Training Loss: 889.7071.. Training Accuracy: 0.6620.. Validation Loss: 876.3717.. Validation Accuracy: 0.6560..
# Epoch: 3/50.. Training Loss: 993.1855.. Training Accuracy: 0.6480.. Validation Loss: 1001.8217.. Validation Accuracy: 0.6420..
# Epoch: 4/50.. Training Loss: 901.3510.. Training Accuracy: 0.6510.. Validation Loss: 928.2288.. Validation Accuracy: 0.6530..
# Epoch: 5/50.. Training Loss: 1074.8889.. Training Accuracy: 0.6090.. Validation Loss: 1104.2389.. Validation Accuracy: 0.6220..
# Epoch: 6/50.. Training Loss: 821.5336.. Training Accuracy: 0.6650.. Validation Loss: 872.0682.. Validation Accuracy: 0.6640..
# Epoch: 7/50.. Training Loss: 798.8139.. Training Accuracy: 0.6760.. Validation Loss: 855.2971.. Validation Accuracy: 0.6670..
# Epoch: 8/50.. Training Loss: 878.7505.. Training Accuracy: 0.6570.. Validation Loss: 939.6639.. Validation Accuracy: 0.6590..
# Epoch: 9/50.. Training Loss: 444.3969.. Training Accuracy: 0.7580.. Validation Loss: 537.2030.. Validation Accuracy: 0.7210..
# Epoch: 10/50.. Training Loss: 931.4343.. Training Accuracy: 0.6420.. Validation Loss: 1002.7186.. Validation Accuracy: 0.6540..
# Epoch: 11/50.. Training Loss: 427.8139.. Training Accuracy: 0.7770.. Validation Loss: 570.0938.. Validation Accuracy: 0.7370..
# Epoch: 12/50.. Training Loss: 445.0864.. Training Accuracy: 0.7780.. Validation Loss: 597.6964.. Validation Accuracy: 0.7340..
# Epoch: 13/50.. Training Loss: 437.0088.. Training Accuracy: 0.7780.. Validation Loss: 592.2877.. Validation Accuracy: 0.7330..
# Epoch: 14/50.. Training Loss: 263.4834.. Training Accuracy: 0.8250.. Validation Loss: 395.6239.. Validation Accuracy: 0.7670..
# Epoch: 15/50.. Training Loss: 531.9969.. Training Accuracy: 0.6910.. Validation Loss: 681.7709.. Validation Accuracy: 0.6880..
# Epoch: 16/50.. Training Loss: 699.5917.. Training Accuracy: 0.6830.. Validation Loss: 842.1879.. Validation Accuracy: 0.6840..
# Epoch: 17/50.. Training Loss: 309.8726.. Training Accuracy: 0.8110.. Validation Loss: 479.6201.. Validation Accuracy: 0.7450..
# Epoch: 18/50.. Training Loss: 706.9282.. Training Accuracy: 0.7230.. Validation Loss: 949.2492.. Validation Accuracy: 0.6800..
# Epoch: 19/50.. Training Loss: 277.2549.. Training Accuracy: 0.8310.. Validation Loss: 443.8807.. Validation Accuracy: 0.7540..
# Epoch: 20/50.. Training Loss: 978.1308.. Training Accuracy: 0.6190.. Validation Loss: 1121.4415.. Validation Accuracy: 0.6350..
# Epoch: 21/50.. Training Loss: 366.6096.. Training Accuracy: 0.7670.. Validation Loss: 541.6432.. Validation Accuracy: 0.7270..
# Epoch: 22/50.. Training Loss: 951.4946.. Training Accuracy: 0.6330.. Validation Loss: 1088.1923.. Validation Accuracy: 0.6580..
# Epoch: 23/50.. Training Loss: 233.7943.. Training Accuracy: 0.8340.. Validation Loss: 398.7964.. Validation Accuracy: 0.7560..
# Epoch: 24/50.. Training Loss: 707.7339.. Training Accuracy: 0.7100.. Validation Loss: 977.7579.. Validation Accuracy: 0.6630..
# Epoch: 25/50.. Training Loss: 271.5362.. Training Accuracy: 0.8290.. Validation Loss: 450.5818.. Validation Accuracy: 0.7590..
# Epoch: 26/50.. Training Loss: 450.0061.. Training Accuracy: 0.7710.. Validation Loss: 680.9700.. Validation Accuracy: 0.7120..
# Epoch: 27/50.. Training Loss: 301.1986.. Training Accuracy: 0.8160.. Validation Loss: 501.5526.. Validation Accuracy: 0.7420..
# Epoch: 28/50.. Training Loss: 830.4825.. Training Accuracy: 0.6590.. Validation Loss: 1017.9676.. Validation Accuracy: 0.6680..
# Epoch: 29/50.. Training Loss: 350.8579.. Training Accuracy: 0.7840.. Validation Loss: 547.8270.. Validation Accuracy: 0.7260..
# Epoch: 30/50.. Training Loss: 354.2344.. Training Accuracy: 0.7620.. Validation Loss: 550.0646.. Validation Accuracy: 0.7200..
# Epoch: 31/50.. Training Loss: 629.7805.. Training Accuracy: 0.7070.. Validation Loss: 811.8950.. Validation Accuracy: 0.6860..
# Epoch: 32/50.. Training Loss: 465.9350.. Training Accuracy: 0.7480.. Validation Loss: 658.3160.. Validation Accuracy: 0.7140..
# Epoch: 33/50.. Training Loss: 243.0050.. Training Accuracy: 0.8230.. Validation Loss: 436.7196.. Validation Accuracy: 0.7440..
# Epoch: 34/50.. Training Loss: 739.4131.. Training Accuracy: 0.7060.. Validation Loss: 1051.3521.. Validation Accuracy: 0.6650..
# Epoch: 35/50.. Training Loss: 224.2311.. Training Accuracy: 0.8430.. Validation Loss: 418.9181.. Validation Accuracy: 0.7620..
# Epoch: 36/50.. Training Loss: 468.8806.. Training Accuracy: 0.7310.. Validation Loss: 666.3390.. Validation Accuracy: 0.6990..
# Epoch: 37/50.. Training Loss: 730.9037.. Training Accuracy: 0.6860.. Validation Loss: 920.3952.. Validation Accuracy: 0.6840..
# Epoch: 38/50.. Training Loss: 216.1826.. Training Accuracy: 0.8470.. Validation Loss: 416.9977.. Validation Accuracy: 0.7550..
# Epoch: 39/50.. Training Loss: 366.9223.. Training Accuracy: 0.7930.. Validation Loss: 630.8064.. Validation Accuracy: 0.7140..
# Epoch: 40/50.. Training Loss: 265.0863.. Training Accuracy: 0.8210.. Validation Loss: 480.0703.. Validation Accuracy: 0.7450..
# Epoch: 41/50.. Training Loss: 437.6320.. Training Accuracy: 0.7430.. Validation Loss: 650.0547.. Validation Accuracy: 0.7050..
# Epoch: 42/50.. Training Loss: 588.3812.. Training Accuracy: 0.7180.. Validation Loss: 802.3955.. Validation Accuracy: 0.6940..
# Epoch: 43/50.. Training Loss: 195.3589.. Training Accuracy: 0.8430.. Validation Loss: 410.1721.. Validation Accuracy: 0.7520..
# Epoch: 44/50.. Training Loss: 279.8630.. Training Accuracy: 0.8290.. Validation Loss: 514.3482.. Validation Accuracy: 0.7470..
# Epoch: 45/50.. Training Loss: 213.6010.. Training Accuracy: 0.8540.. Validation Loss: 429.9497.. Validation Accuracy: 0.7570..
# Epoch: 46/50.. Training Loss: 539.0975.. Training Accuracy: 0.7120.. Validation Loss: 753.4589.. Validation Accuracy: 0.6860..
# Epoch: 47/50.. Training Loss: 655.0065.. Training Accuracy: 0.7040.. Validation Loss: 875.0061.. Validation Accuracy: 0.6940..
# Epoch: 48/50.. Training Loss: 332.8809.. Training Accuracy: 0.7890.. Validation Loss: 558.6179.. Validation Accuracy: 0.7280..
# Epoch: 49/50.. Training Loss: 395.3729.. Training Accuracy: 0.7660.. Validation Loss: 702.4977.. Validation Accuracy: 0.7010..
# Epoch: 50/50.. Training Loss: 277.9286.. Training Accuracy: 0.8260.. Validation Loss: 525.4041.. Validation Accuracy: 0.7510..
# The Best Validation Accuracy is : 0.7670..

# %%
import numpy as np
np.save('save/train_loss_mlp1.npy',np.array(train_loss_mlp1 ))
np.save('save/train_accuracy_mlp1.npy',np.array(train_accuracy_mlp1 ))
np.save('save/test_loss_mlp1.npy',np.array(test_loss_mlp1 ))
np.save('save/test_accuracy_mlp1.npy',np.array(test_accuracy_mlp1 ))

# %% [markdown]
# ### 3.2 3-Layer MLP

# %%
model_mlp3=MLP(nb_layer=3,nb_hidden_neuron=100)
model_mlp1.apply(weights_init)
model_mlp3,train_loss_mlp3,train_accuracy_mlp3, test_loss_mlp3,test_accuracy_mlp3=train_model(model_mlp3,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_mlp3,train_accuracy_mlp3, test_loss_mlp3,test_accuracy_mlp3, 'Learning Curve of 3-layer MLP')
# Out:
# The Best Validation Accuracy is : 0.7570..

# %%
import numpy as np
np.save('save/train_loss_mlp3.npy',np.array(train_loss_mlp3 ))
np.save('save/train_accuracy_mlp3.npy',np.array(train_accuracy_mlp3 ))
np.save('save/test_loss_mlp3.npy',np.array(test_loss_mlp3 ))
np.save('save/test_accuracy_mlp3.npy',np.array(test_accuracy_mlp3 ))

# %% [markdown]
# # 4. Simple Convolution Network

# %% [markdown]
# ### 4.1 First CNN (shrinking fast)

# %%
class ConvNet_1(nn.Module):
    def __init__(self, bn=False, dropout=0, activation='relu' ):
        super(ConvNet_1, self).__init__()
        self.conv1 = nn.Conv2d(2, 8, kernel_size=3)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*2*2 ,64)
        self.fc2 = nn.Linear(64, 2)
        self.bn16 = torch.nn.BatchNorm2d(16)
        self.bn16 = torch.nn.BatchNorm2d(32)
        self.bn=bn
        self.activation=activation
        self.dropout=dropout

    def forward(self, x):
        x=self.conv1(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
            
        x=F.max_pool2d(x, kernel_size=2, stride=2)
            
        x=self.conv2(x)
        if self.bn:
            x=self.bn16(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
            
        x=F.max_pool2d(x, kernel_size=2, stride=2)
        
        x = F.dropout(x, p=self.dropout,training=self.training)
        
        
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x = self.fc2(x)
    
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
model_cnn1=ConvNet_1()
model_cnn1.apply(weights_init)
model_cnn1,train_loss_cnn1,train_accuracy_cnn1, test_loss_cnn1,test_accuracy_cnn1=train_model(model_cnn1,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_cnn1,train_accuracy_cnn1, test_loss_cnn1,test_accuracy_cnn1, 'Learning Curve of First ConvNet')
# Out:
# The Best Validation Accuracy is : 0.7120..

# %%
import numpy as np
np.save('save/train_loss_cnn1.npy',np.array(train_loss_cnn1 ))
np.save('save/train_accuracy_cnn1.npy',np.array(train_accuracy_cnn1 ))
np.save('save/test_loss_cnn1.npy',np.array(test_loss_cnn1 ))
np.save('save/test_accuracy_cnn1.npy',np.array(test_accuracy_cnn1 ))

# %% [markdown]
# ### 4.2 Second CNN (shrinking slow)

# %%
class ConvNet_2(nn.Module):
    def __init__(self, bn=False, dropout=0, activation='relu' ):
        super(ConvNet_2, self).__init__()
        self.conv1 = nn.Conv2d(2, 8, kernel_size=3,padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*6*6 ,64)
        self.fc2 = nn.Linear(64, 2)
        self.bn8 = torch.nn.BatchNorm2d(8)
        self.bn16 = torch.nn.BatchNorm2d(16)
        self.bn32 = torch.nn.BatchNorm2d(32)
        self.bn=bn
        self.activation=activation
        self.dropout=dropout
    def forward(self, x):
        x=self.conv1(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
            
        if self.bn:
            x=self.bn8(x)
            
        x=self.conv2(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
        if self.bn:
            x=self.bn16(x)
        
        x = F.dropout(x, p=self.dropout,training=self.training)
         
        x=F.max_pool2d(x, kernel_size=2, stride=2)
        
        
        
        
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x = self.fc2(x)
    
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
model_cnn2=ConvNet_2()
model_cnn2.apply(weights_init)
model_cnn2,train_loss_cnn2,train_accuracy_cnn2, test_loss_cnn2,test_accuracy_cnn2=train_model(model_cnn2,if_print=True, learning_rate=0.01)
evaluate_result(train_loss_cnn2,train_accuracy_cnn2, test_loss_cnn2,test_accuracy_cnn2, 'Learning Curve of Second ConvNet')
# Out:
# Epoch: 1/50.. Training Loss: 0.6821.. Training Accuracy: 0.5710.. Validation Loss: 0.6814.. Validation Accuracy: 0.5800..
# Epoch: 2/50.. Training Loss: 0.6637.. Training Accuracy: 0.6200.. Validation Loss: 0.6668.. Validation Accuracy: 0.6190..
# Epoch: 3/50.. Training Loss: 0.6413.. Training Accuracy: 0.6630.. Validation Loss: 0.6479.. Validation Accuracy: 0.6560..
# Epoch: 4/50.. Training Loss: 0.6029.. Training Accuracy: 0.6890.. Validation Loss: 0.6151.. Validation Accuracy: 0.6920..
# Epoch: 5/50.. Training Loss: 0.5573.. Training Accuracy: 0.7270.. Validation Loss: 0.5824.. Validation Accuracy: 0.7040..
# Epoch: 6/50.. Training Loss: 0.5311.. Training Accuracy: 0.7270.. Validation Loss: 0.5672.. Validation Accuracy: 0.7140..
# Epoch: 7/50.. Training Loss: 0.5121.. Training Accuracy: 0.7390.. Validation Loss: 0.5574.. Validation Accuracy: 0.7270..
# Epoch: 8/50.. Training Loss: 0.4928.. Training Accuracy: 0.7520.. Validation Loss: 0.5459.. Validation Accuracy: 0.7370..
# Epoch: 9/50.. Training Loss: 0.4707.. Training Accuracy: 0.7710.. Validation Loss: 0.5299.. Validation Accuracy: 0.7430..
# Epoch: 10/50.. Training Loss: 0.4533.. Training Accuracy: 0.7900.. Validation Loss: 0.5182.. Validation Accuracy: 0.7440..
# Epoch: 11/50.. Training Loss: 0.4458.. Training Accuracy: 0.7970.. Validation Loss: 0.5147.. Validation Accuracy: 0.7540..
# Epoch: 12/50.. Training Loss: 0.4372.. Training Accuracy: 0.8040.. Validation Loss: 0.5134.. Validation Accuracy: 0.7520..
# Epoch: 13/50.. Training Loss: 0.4231.. Training Accuracy: 0.8110.. Validation Loss: 0.5104.. Validation Accuracy: 0.7540..
# Epoch: 14/50.. Training Loss: 0.4203.. Training Accuracy: 0.8130.. Validation Loss: 0.5118.. Validation Accuracy: 0.7550..
# Epoch: 15/50.. Training Loss: 0.4130.. Training Accuracy: 0.8180.. Validation Loss: 0.5093.. Validation Accuracy: 0.7510..
# Epoch: 16/50.. Training Loss: 0.3882.. Training Accuracy: 0.8260.. Validation Loss: 0.5090.. Validation Accuracy: 0.7600..
# Epoch: 17/50.. Training Loss: 0.5801.. Training Accuracy: 0.7100.. Validation Loss: 0.7477.. Validation Accuracy: 0.6670..
# Epoch: 18/50.. Training Loss: 0.3751.. Training Accuracy: 0.8360.. Validation Loss: 0.5161.. Validation Accuracy: 0.7690..
# Epoch: 19/50.. Training Loss: 0.3590.. Training Accuracy: 0.8440.. Validation Loss: 0.5119.. Validation Accuracy: 0.7690..
# Epoch: 20/50.. Training Loss: 0.3757.. Training Accuracy: 0.8340.. Validation Loss: 0.5197.. Validation Accuracy: 0.7500..
# Epoch: 21/50.. Training Loss: 0.3678.. Training Accuracy: 0.8430.. Validation Loss: 0.5024.. Validation Accuracy: 0.7520..
# Epoch: 22/50.. Training Loss: 0.3357.. Training Accuracy: 0.8550.. Validation Loss: 0.5167.. Validation Accuracy: 0.7710..
# Epoch: 23/50.. Training Loss: 0.5630.. Training Accuracy: 0.7160.. Validation Loss: 0.7561.. Validation Accuracy: 0.6620..
# Epoch: 24/50.. Training Loss: 0.3245.. Training Accuracy: 0.8530.. Validation Loss: 0.5084.. Validation Accuracy: 0.7630..
# Epoch: 25/50.. Training Loss: 0.3701.. Training Accuracy: 0.8410.. Validation Loss: 0.5337.. Validation Accuracy: 0.7350..
# Epoch: 26/50.. Training Loss: 0.3133.. Training Accuracy: 0.8630.. Validation Loss: 0.5120.. Validation Accuracy: 0.7610..
# Epoch: 27/50.. Training Loss: 0.3519.. Training Accuracy: 0.8480.. Validation Loss: 0.5360.. Validation Accuracy: 0.7380..
# Epoch: 28/50.. Training Loss: 0.2881.. Training Accuracy: 0.8770.. Validation Loss: 0.5146.. Validation Accuracy: 0.7660..
# Epoch: 29/50.. Training Loss: 0.5042.. Training Accuracy: 0.7330.. Validation Loss: 0.7336.. Validation Accuracy: 0.6750..
# Epoch: 30/50.. Training Loss: 0.2738.. Training Accuracy: 0.8840.. Validation Loss: 0.5293.. Validation Accuracy: 0.7700..
# Epoch: 31/50.. Training Loss: 0.3520.. Training Accuracy: 0.8380.. Validation Loss: 0.6377.. Validation Accuracy: 0.7260..
# Epoch: 32/50.. Training Loss: 0.2536.. Training Accuracy: 0.8950.. Validation Loss: 0.5211.. Validation Accuracy: 0.7630..
# Epoch: 33/50.. Training Loss: 0.2967.. Training Accuracy: 0.8830.. Validation Loss: 0.4999.. Validation Accuracy: 0.7520..
# Epoch: 34/50.. Training Loss: 0.2538.. Training Accuracy: 0.8960.. Validation Loss: 0.5662.. Validation Accuracy: 0.7700..
# Epoch: 35/50.. Training Loss: 0.3479.. Training Accuracy: 0.8330.. Validation Loss: 0.6857.. Validation Accuracy: 0.7210..
# Epoch: 36/50.. Training Loss: 0.2217.. Training Accuracy: 0.9150.. Validation Loss: 0.5324.. Validation Accuracy: 0.7750..
# Epoch: 37/50.. Training Loss: 0.2672.. Training Accuracy: 0.9020.. Validation Loss: 0.4993.. Validation Accuracy: 0.7660..
# Epoch: 38/50.. Training Loss: 0.2249.. Training Accuracy: 0.9150.. Validation Loss: 0.5794.. Validation Accuracy: 0.7660..
# Epoch: 39/50.. Training Loss: 0.3043.. Training Accuracy: 0.8550.. Validation Loss: 0.6904.. Validation Accuracy: 0.7240..
# Epoch: 40/50.. Training Loss: 0.1936.. Training Accuracy: 0.9370.. Validation Loss: 0.5602.. Validation Accuracy: 0.7700..
# Epoch: 41/50.. Training Loss: 0.2616.. Training Accuracy: 0.8860.. Validation Loss: 0.5221.. Validation Accuracy: 0.7410..
# Epoch: 42/50.. Training Loss: 0.1821.. Training Accuracy: 0.9470.. Validation Loss: 0.5806.. Validation Accuracy: 0.7690..
# Epoch: 43/50.. Training Loss: 0.3323.. Training Accuracy: 0.8280.. Validation Loss: 0.7908.. Validation Accuracy: 0.7050..
# Epoch: 44/50.. Training Loss: 0.1652.. Training Accuracy: 0.9340.. Validation Loss: 0.5607.. Validation Accuracy: 0.7690..
# Epoch: 45/50.. Training Loss: 0.1780.. Training Accuracy: 0.9280.. Validation Loss: 0.5423.. Validation Accuracy: 0.7600..
# Epoch: 46/50.. Training Loss: 0.1519.. Training Accuracy: 0.9600.. Validation Loss: 0.5929.. Validation Accuracy: 0.7640..
# Epoch: 47/50.. Training Loss: 0.1470.. Training Accuracy: 0.9600.. Validation Loss: 0.5981.. Validation Accuracy: 0.7660..
# Epoch: 48/50.. Training Loss: 0.1325.. Training Accuracy: 0.9650.. Validation Loss: 0.5972.. Validation Accuracy: 0.7650..
# Epoch: 49/50.. Training Loss: 0.2127.. Training Accuracy: 0.8980.. Validation Loss: 0.6679.. Validation Accuracy: 0.7390..
# Epoch: 50/50.. Training Loss: 0.1416.. Training Accuracy: 0.9520.. Validation Loss: 0.5739.. Validation Accuracy: 0.7590..
# The Best Validation Accuracy is : 0.7750..

# %%
import numpy as np
np.save('save/train_loss_cnn2.npy',np.array(train_loss_cnn2 ))
np.save('save/train_accuracy_cnn2.npy',np.array(train_accuracy_cnn2 ))
np.save('save/test_loss_cnn2.npy',np.array(test_loss_cnn2 ))
np.save('save/test_accuracy_cnn2.npy',np.array(test_accuracy_cnn2 ))

# %% [markdown]
# # Comparison among MLP and CNN

# %%
import numpy as np
train_loss_mlp1=np.load('save/train_loss_mlp1.npy')
train_accuracy_mlp1=np.load('save/train_accuracy_mlp1.npy')
test_loss_mlp1=np.load('save/test_loss_mlp1.npy')
test_accuracy_mlp1=np.load('save/test_accuracy_mlp1.npy')

# %%
train_loss_mlp3=np.load('save/train_loss_mlp3.npy')
train_accuracy_mlp3=np.load('save/train_accuracy_mlp3.npy')
test_loss_mlp3=np.load('save/test_loss_mlp3.npy')
test_accuracy_mlp3=np.load('save/test_accuracy_mlp3.npy')

# %%
train_loss_cnn1=np.load('save/train_loss_cnn1.npy')
train_accuracy_cnn1=np.load('save/train_accuracy_cnn1.npy')
test_loss_cnn1=np.load('save/test_loss_cnn1.npy')
test_accuracy_cnn1=np.load('save/test_accuracy_cnn1.npy')

# %%
train_loss_cnn2=np.load('save/train_loss_cnn2.npy')
train_accuracy_cnn2=np.load('save/train_accuracy_cnn2.npy')
test_loss_cnn2=np.load('save/test_loss_cnn2.npy')
test_accuracy_cnn2=np.load('save/test_accuracy_cnn2.npy')

# %%
plot_different_histories(train_loss_mlp1,train_accuracy_mlp1, test_loss_mlp1,test_accuracy_mlp1,
                             train_loss_mlp3,train_accuracy_mlp3, test_loss_mlp3,test_accuracy_mlp3,
                             train_loss_cnn1,train_accuracy_cnn1,test_loss_cnn1,test_accuracy_cnn1,
                             train_loss_cnn2,train_accuracy_cnn2, test_loss_cnn2,test_accuracy_cnn2,
                             label_1='1-layer MLP', label_2='3-layer MLP', label_3='1st CNN', label_4='2nd CNN',
                             title='Learning Curves of MLP and CNN')

# %% [markdown]
# ### 4.3 Regularization

# %% [markdown]
# ### 4.3.1 Dropout

# %%
model_cnn2_dp=ConvNet_2(dropout=0.4)
model_cnn2_dp.apply(weights_init)
model_cnn2_dp,train_loss_cnn2_dp,train_accuracy_cnn2_dp, test_loss_cnn2_dp,test_accuracy_cnn2_dp=\
           train_model(model_cnn2_dp,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_cnn2_dp,train_accuracy_cnn2_dp, test_loss_cnn2_dp,test_accuracy_cnn2_dp, \
                'Learning Curve of Second ConvNet with Dropout 0.4')
# Out:
# The Best Validation Accuracy is : 0.7410..

# %%
import numpy as np
np.save('save/train_loss_cnn2_dp.npy',np.array(train_loss_cnn2_dp ))
np.save('save/train_accuracy_cnn2_dp.npy',np.array(train_accuracy_cnn2_dp ))
np.save('save/test_loss_cnn2_dp.npy',np.array(test_loss_cnn2_dp ))
np.save('save/test_accuracy_cnn2_dp.npy',np.array(test_accuracy_cnn2_dp ))

# %% [markdown]
# ### 4.3.2 Adding Batch  Normalization

# %%
model_cnn2_bn=ConvNet_2(bn=True)
model_cnn2_bn.apply(weights_init)
model_cnn2_bn,train_loss_cnn2_bn,train_accuracy_cnn2_bn, test_loss_cnn2_bn,test_accuracy_cnn2_bn=\
           train_model(model_cnn2_bn,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_cnn2_bn,train_accuracy_cnn2_bn, test_loss_cnn2_bn,test_accuracy_cnn2_bn, \
                'Learning Curve of Second ConvNet with Batch Normalization')
# Out:
# The Best Validation Accuracy is : 0.7850..

# %%
import numpy as np
np.save('save/train_loss_cnn2_bn.npy',np.array(train_loss_cnn2_bn ))
np.save('save/train_accuracy_cnn2_bn.npy',np.array(train_accuracy_cnn2_bn ))
np.save('save/test_loss_cnn2_bn.npy',np.array(test_loss_cnn2_bn ))
np.save('save/test_accuracy_cnn2_bn.npy',np.array(test_accuracy_cnn2_bn ))

# %% [markdown]
# ### 4.4 Change the Activation Function

# %%
model_cnn2_sigmoid=ConvNet_2(activation='sigmoid')
model_cnn2_sigmoid.apply(weights_init)
model_cnn2_sigmoid,train_loss_cnn2_sigmoid,train_accuracy_cnn2_sigmoid, test_loss_cnn2_sigmoid,test_accuracy_cnn2_sigmoid=\
                                  train_model(model_cnn2_sigmoid,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_cnn2_sigmoid,train_accuracy_cnn2_sigmoid, test_loss_cnn2_sigmoid,test_accuracy_cnn2_sigmoid,\
                'Learning Curve of Second ConvNet with Sigmoid Activation')
# Out:
# The Best Validation Accuracy is : 0.5260..

# %%
import numpy as np
np.save('save/train_loss_cnn2_sigmoid.npy',np.array(train_loss_cnn2_sigmoid ))
np.save('save/train_accuracy_cnn2_sigmoid.npy',np.array(train_accuracy_cnn2_sigmoid ))
np.save('save/test_loss_cnn2_sigmoid.npy',np.array(test_loss_cnn2_sigmoid ))
np.save('save/test_accuracy_cnn2_sigmoid.npy',np.array(test_accuracy_cnn2_sigmoid ))

# %%
model_cnn2_sigmoid_bn=ConvNet_2(activation='sigmoid',bn=True)
model_cnn2_sigmoid_bn.apply(weights_init)
model_cnn2_sigmoid_bn,train_loss_cnn2_sigmoid_bn,train_accuracy_cnn2_sigmoid_bn, test_loss_cnn2_sigmoid_bn,test_accuracy_cnn2_sigmoid_bn=\
                                  train_model(model_cnn2_sigmoid_bn,if_print=False, learning_rate=0.01)
evaluate_result(train_loss_cnn2_sigmoid_bn,train_accuracy_cnn2_sigmoid_bn, test_loss_cnn2_sigmoid_bn,test_accuracy_cnn2_sigmoid_bn,\
                'Learning Curve of Second ConvNet with Sigmoid Activation and Batch Normalization')
# Out:
# The Best Validation Accuracy is : 0.7460..

# %%
import numpy as np
np.save('save/train_loss_cnn2_sigmoid_bn.npy',np.array(train_loss_cnn2_sigmoid_bn ))
np.save('save/train_accuracy_cnn2_sigmoid_bn.npy',np.array(train_accuracy_cnn2_sigmoid_bn ))
np.save('save/test_loss_cnn2_sigmoid_bn.npy',np.array(test_loss_cnn2_sigmoid_bn ))
np.save('save/test_accuracy_cnn2_sigmoid_bn.npy',np.array(test_accuracy_cnn2_sigmoid_bn ))

# %% [markdown]
# ### 4.5 Going Deep

# %%
class DeepNet(nn.Module):
    '''
    define Deeper CNN model 
   
    '''
    def __init__(self):
        super(DeepNet, self).__init__()
        self.conv1 = nn.Conv2d(2, 8, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv8 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16*6*6 ,64)
        self.fc2 = nn.Linear(64, 2)
        self.bn8 = torch.nn.BatchNorm2d(8)
        

    def forward(self, x):
        x=self.conv1(x)
        x=F.relu(x)
        x=self.conv2(x)
        x=F.relu(x)
        x=F.max_pool2d(x, kernel_size=2, stride=2)
        
        
        # after this, build 6 same convolution layers
        x=self.conv3(x)
        x=F.relu(x)
        
        x=self.conv4(x)
        x=F.relu(x)
        
        x=self.conv5(x)
        x=F.relu(x)
        
        x=self.conv6(x)
        x=F.relu(x)
        
        x=self.conv7(x)
        x=F.relu(x)
        
        x=self.conv8(x)
        x=F.relu(x)
        
        
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x = self.fc2(x)
    
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
model_deep=DeepNet()
model_deep.apply(weights_init)
model_deep,train_loss_deep,train_accuracy_deep, test_loss_deep,test_accuracy_deep=train_model(model_deep,if_print=True, learning_rate=0.01)
evaluate_result(train_loss_deep,train_accuracy_deep, test_loss_deep,test_accuracy_deep, 'Learning Curve of Deeper Net')
# Out:
# Epoch: 1/50.. Training Loss: 0.6889.. Training Accuracy: 0.5510.. Validation Loss: 0.6918.. Validation Accuracy: 0.5260..
# Epoch: 2/50.. Training Loss: 0.6888.. Training Accuracy: 0.5510.. Validation Loss: 0.6919.. Validation Accuracy: 0.5260..
# Epoch: 3/50.. Training Loss: 0.6887.. Training Accuracy: 0.5510.. Validation Loss: 0.6919.. Validation Accuracy: 0.5260..
# Epoch: 4/50.. Training Loss: 0.6886.. Training Accuracy: 0.5510.. Validation Loss: 0.6919.. Validation Accuracy: 0.5260..
# Epoch: 5/50.. Training Loss: 0.6885.. Training Accuracy: 0.5510.. Validation Loss: 0.6919.. Validation Accuracy: 0.5260..
# Epoch: 6/50.. Training Loss: 0.6885.. Training Accuracy: 0.5510.. Validation Loss: 0.6920.. Validation Accuracy: 0.5260..
# Epoch: 7/50.. Training Loss: 0.6884.. Training Accuracy: 0.5510.. Validation Loss: 0.6920.. Validation Accuracy: 0.5260..
# Epoch: 8/50.. Training Loss: 0.6883.. Training Accuracy: 0.5510.. Validation Loss: 0.6921.. Validation Accuracy: 0.5260..
# Epoch: 9/50.. Training Loss: 0.6883.. Training Accuracy: 0.5510.. Validation Loss: 0.6921.. Validation Accuracy: 0.5260..
# Epoch: 10/50.. Training Loss: 0.6882.. Training Accuracy: 0.5510.. Validation Loss: 0.6922.. Validation Accuracy: 0.5260..
# Epoch: 11/50.. Training Loss: 0.6882.. Training Accuracy: 0.5510.. Validation Loss: 0.6922.. Validation Accuracy: 0.5260..
# Epoch: 12/50.. Training Loss: 0.6882.. Training Accuracy: 0.5510.. Validation Loss: 0.6922.. Validation Accuracy: 0.5260..
# Epoch: 13/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6923.. Validation Accuracy: 0.5260..
# Epoch: 14/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6923.. Validation Accuracy: 0.5260..
# Epoch: 15/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6923.. Validation Accuracy: 0.5260..
# Epoch: 16/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6924.. Validation Accuracy: 0.5260..
# Epoch: 17/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6924.. Validation Accuracy: 0.5260..
# Epoch: 18/50.. Training Loss: 0.6881.. Training Accuracy: 0.5510.. Validation Loss: 0.6925.. Validation Accuracy: 0.5260..
# Epoch: 19/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6925.. Validation Accuracy: 0.5260..
# Epoch: 20/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6925.. Validation Accuracy: 0.5260..
# Epoch: 21/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6925.. Validation Accuracy: 0.5260..
# Epoch: 22/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6926.. Validation Accuracy: 0.5260..
# Epoch: 23/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6926.. Validation Accuracy: 0.5260..
# Epoch: 24/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6926.. Validation Accuracy: 0.5260..
# Epoch: 25/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6927.. Validation Accuracy: 0.5260..
# Epoch: 26/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6927.. Validation Accuracy: 0.5260..
# Epoch: 27/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6927.. Validation Accuracy: 0.5260..
# Epoch: 28/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6927.. Validation Accuracy: 0.5260..
# Epoch: 29/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6927.. Validation Accuracy: 0.5260..
# Epoch: 30/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 31/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 32/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 33/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 34/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 35/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 36/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6928.. Validation Accuracy: 0.5260..
# Epoch: 37/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 38/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 39/50.. Training Loss: 0.6880.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 40/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 41/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 42/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 43/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 44/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 45/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 46/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 47/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 48/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 49/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# Epoch: 50/50.. Training Loss: 0.6879.. Training Accuracy: 0.5510.. Validation Loss: 0.6929.. Validation Accuracy: 0.5260..
# The Best Validation Accuracy is : 0.5260..

# %%
import numpy as np
np.save('save/train_loss_deep.npy',np.array(train_loss_deep))
np.save('save/train_accuracy_deep.npy',np.array(train_accuracy_deep ))
np.save('save/test_loss_deep.npy',np.array(test_loss_deep ))
np.save('save/test_accuracy_deep.npy',np.array(test_accuracy_deep ))

# %% [markdown]
# ### 4.5.2 Going Deeper with Residual Block

# %%
class DeepNet_Res(nn.Module):
    '''
    define Deeper CNN model with residual block
   
    '''
    def __init__(self):
        super(DeepNet_Res, self).__init__()
        self.conv1 = nn.Conv2d(2, 8, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(16*6*6 ,64)
        self.fc2 = nn.Linear(64, 2)
        self.conv4 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
        self.conv8 = nn.Conv2d(16, 16, kernel_size=3, padding=1)
 

    def forward(self, x):
        x=self.conv1(x)
        x=F.relu(x)
        x=self.conv2(x)
        x=F.relu(x)
        x=F.max_pool2d(x, kernel_size=2, stride=2)
        

        # for later residual operation
        x1=x
        # after this, build 6 same convolution layers
        x=self.conv3(x)
        x=F.relu(x)
        
        x=self.conv4(x)
        x=F.relu(x)
        
        x=self.conv5(x)
        x=F.relu(x)
        
        # residual operation
        x=x1+x
        # for later residual operation
        x2=x
        
        x=self.conv6(x)
        x=F.relu(x)
        
        x=self.conv7(x)
        x=F.relu(x)
        
        x=self.conv8(x)
        x=F.relu(x)
        
        #  residual operation
        x=x2+x
       
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x = self.fc2(x)
    
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
model_deep_res=DeepNet_Res()
model_deep_res.apply(weights_init)
model_deep_res,train_loss_deep_res,train_accuracy_deep_res, test_loss_deep_res,test_accuracy_deep_res=\
                              train_model(model_deep_res,if_print=True, learning_rate=0.01)
evaluate_result(train_loss_deep_res,train_accuracy_deep_res, test_loss_deep_res,test_accuracy_deep_res,
                'Learning Curve of Deeper NeT with Residual Block')
# Out:
# Epoch: 1/50.. Training Loss: 0.6746.. Training Accuracy: 0.5860.. Validation Loss: 0.6841.. Validation Accuracy: 0.5620..
# Epoch: 2/50.. Training Loss: 0.6455.. Training Accuracy: 0.6280.. Validation Loss: 0.6609.. Validation Accuracy: 0.5910..
# Epoch: 3/50.. Training Loss: 0.6118.. Training Accuracy: 0.6800.. Validation Loss: 0.6392.. Validation Accuracy: 0.6310..
# Epoch: 4/50.. Training Loss: 0.5970.. Training Accuracy: 0.6730.. Validation Loss: 0.6316.. Validation Accuracy: 0.6540..
# Epoch: 5/50.. Training Loss: 0.5764.. Training Accuracy: 0.6950.. Validation Loss: 0.6231.. Validation Accuracy: 0.6500..
# Epoch: 6/50.. Training Loss: 0.5743.. Training Accuracy: 0.7010.. Validation Loss: 0.6184.. Validation Accuracy: 0.6590..
# Epoch: 7/50.. Training Loss: 0.5701.. Training Accuracy: 0.7100.. Validation Loss: 0.6079.. Validation Accuracy: 0.6740..
# Epoch: 8/50.. Training Loss: 0.5374.. Training Accuracy: 0.7220.. Validation Loss: 0.6110.. Validation Accuracy: 0.6640..
# Epoch: 9/50.. Training Loss: 0.5287.. Training Accuracy: 0.7320.. Validation Loss: 0.6061.. Validation Accuracy: 0.6700..
# Epoch: 10/50.. Training Loss: 0.5225.. Training Accuracy: 0.7480.. Validation Loss: 0.5939.. Validation Accuracy: 0.6840..
# Epoch: 11/50.. Training Loss: 0.5088.. Training Accuracy: 0.7570.. Validation Loss: 0.5971.. Validation Accuracy: 0.6790..
# Epoch: 12/50.. Training Loss: 0.4914.. Training Accuracy: 0.7670.. Validation Loss: 0.5951.. Validation Accuracy: 0.6760..
# Epoch: 13/50.. Training Loss: 0.5011.. Training Accuracy: 0.7680.. Validation Loss: 0.5984.. Validation Accuracy: 0.6710..
# Epoch: 14/50.. Training Loss: 0.5116.. Training Accuracy: 0.7470.. Validation Loss: 0.6010.. Validation Accuracy: 0.6880..
# Epoch: 15/50.. Training Loss: 0.4788.. Training Accuracy: 0.7710.. Validation Loss: 0.5896.. Validation Accuracy: 0.6850..
# Epoch: 16/50.. Training Loss: 0.4643.. Training Accuracy: 0.7840.. Validation Loss: 0.5906.. Validation Accuracy: 0.6760..
# Epoch: 17/50.. Training Loss: 0.4503.. Training Accuracy: 0.7870.. Validation Loss: 0.5923.. Validation Accuracy: 0.6880..
# Epoch: 18/50.. Training Loss: 0.4537.. Training Accuracy: 0.7980.. Validation Loss: 0.5993.. Validation Accuracy: 0.6820..
# Epoch: 19/50.. Training Loss: 0.4424.. Training Accuracy: 0.8010.. Validation Loss: 0.6006.. Validation Accuracy: 0.7020..
# Epoch: 20/50.. Training Loss: 0.4361.. Training Accuracy: 0.8170.. Validation Loss: 0.6042.. Validation Accuracy: 0.6800..
# Epoch: 21/50.. Training Loss: 0.4065.. Training Accuracy: 0.8220.. Validation Loss: 0.6024.. Validation Accuracy: 0.6780..
# Epoch: 22/50.. Training Loss: 0.4268.. Training Accuracy: 0.8110.. Validation Loss: 0.6151.. Validation Accuracy: 0.6920..
# Epoch: 23/50.. Training Loss: 0.3980.. Training Accuracy: 0.8330.. Validation Loss: 0.6102.. Validation Accuracy: 0.6850..
# Epoch: 24/50.. Training Loss: 0.3999.. Training Accuracy: 0.8150.. Validation Loss: 0.6219.. Validation Accuracy: 0.7060..
# Epoch: 25/50.. Training Loss: 0.4418.. Training Accuracy: 0.8050.. Validation Loss: 0.6380.. Validation Accuracy: 0.6760..
# Epoch: 26/50.. Training Loss: 0.3706.. Training Accuracy: 0.8540.. Validation Loss: 0.6266.. Validation Accuracy: 0.6720..
# Epoch: 27/50.. Training Loss: 0.3784.. Training Accuracy: 0.8270.. Validation Loss: 0.6361.. Validation Accuracy: 0.6990..
# Epoch: 28/50.. Training Loss: 0.3695.. Training Accuracy: 0.8300.. Validation Loss: 0.6437.. Validation Accuracy: 0.6960..
# Epoch: 29/50.. Training Loss: 0.4310.. Training Accuracy: 0.8020.. Validation Loss: 0.6555.. Validation Accuracy: 0.6610..
# Epoch: 30/50.. Training Loss: 0.3610.. Training Accuracy: 0.8430.. Validation Loss: 0.6500.. Validation Accuracy: 0.6750..
# Epoch: 31/50.. Training Loss: 0.3388.. Training Accuracy: 0.8680.. Validation Loss: 0.6370.. Validation Accuracy: 0.6840..
# Epoch: 32/50.. Training Loss: 0.3564.. Training Accuracy: 0.8390.. Validation Loss: 0.6781.. Validation Accuracy: 0.6960..
# Epoch: 33/50.. Training Loss: 0.4147.. Training Accuracy: 0.8020.. Validation Loss: 0.7235.. Validation Accuracy: 0.6620..
# Epoch: 34/50.. Training Loss: 0.3625.. Training Accuracy: 0.8310.. Validation Loss: 0.6654.. Validation Accuracy: 0.6770..
# Epoch: 35/50.. Training Loss: 0.3086.. Training Accuracy: 0.8740.. Validation Loss: 0.6783.. Validation Accuracy: 0.6960..
# Epoch: 36/50.. Training Loss: 0.3798.. Training Accuracy: 0.8190.. Validation Loss: 0.7165.. Validation Accuracy: 0.6780..
# Epoch: 37/50.. Training Loss: 0.3427.. Training Accuracy: 0.8660.. Validation Loss: 0.6759.. Validation Accuracy: 0.6650..
# Epoch: 38/50.. Training Loss: 0.2941.. Training Accuracy: 0.8780.. Validation Loss: 0.7156.. Validation Accuracy: 0.7080..
# Epoch: 39/50.. Training Loss: 0.3016.. Training Accuracy: 0.8720.. Validation Loss: 0.7079.. Validation Accuracy: 0.6820..
# Epoch: 40/50.. Training Loss: 0.3325.. Training Accuracy: 0.8620.. Validation Loss: 0.7330.. Validation Accuracy: 0.6900..
# Epoch: 41/50.. Training Loss: 0.3750.. Training Accuracy: 0.8240.. Validation Loss: 0.7866.. Validation Accuracy: 0.6760..
# Epoch: 42/50.. Training Loss: 0.3702.. Training Accuracy: 0.8330.. Validation Loss: 0.7214.. Validation Accuracy: 0.6610..
# Epoch: 43/50.. Training Loss: 0.3337.. Training Accuracy: 0.8310.. Validation Loss: 0.8655.. Validation Accuracy: 0.6760..
# Epoch: 44/50.. Training Loss: 0.2657.. Training Accuracy: 0.8930.. Validation Loss: 0.7473.. Validation Accuracy: 0.6860..
# Epoch: 45/50.. Training Loss: 0.4389.. Training Accuracy: 0.7910.. Validation Loss: 1.0006.. Validation Accuracy: 0.6600..
# Epoch: 46/50.. Training Loss: 0.3669.. Training Accuracy: 0.8250.. Validation Loss: 0.8452.. Validation Accuracy: 0.6630..
# Epoch: 47/50.. Training Loss: 0.2498.. Training Accuracy: 0.9100.. Validation Loss: 0.7767.. Validation Accuracy: 0.6930..
# Epoch: 48/50.. Training Loss: 0.3156.. Training Accuracy: 0.8520.. Validation Loss: 0.9287.. Validation Accuracy: 0.6830..
# Epoch: 49/50.. Training Loss: 0.2429.. Training Accuracy: 0.9170.. Validation Loss: 0.8103.. Validation Accuracy: 0.6980..
# Epoch: 50/50.. Training Loss: 0.5429.. Training Accuracy: 0.7830.. Validation Loss: 1.1765.. Validation Accuracy: 0.6630..
# The Best Validation Accuracy is : 0.7080..

# %%
import numpy as np
np.save('save/train_loss_deep_res.npy',np.array(train_loss_deep_res))
np.save('save/train_accuracy_deep_res.npy',np.array(train_accuracy_deep_res ))
np.save('save/test_loss_deep_res.npy',np.array(test_loss_deep_res ))
np.save('save/test_accuracy_deep_res.npy',np.array(test_accuracy_deep_res ))

# %% [markdown]
# ### Comparison with Original CNN and CNN with Tricks

# %%
import numpy as np
train_loss_cnn2_bn=np.load('save/train_loss_cnn2_bn.npy')
train_accuracy_cnn2_bn=np.load('save/train_accuracy_cnn2_bn.npy')
test_loss_cnn2_bn=np.load('save/test_loss_cnn2_bn.npy')
test_accuracy_cnn2_bn=np.load('save/test_accuracy_cnn2_bn.npy')

# %%
train_loss_cnn2_sigmoid_bn=np.load('save/train_loss_cnn2_sigmoid_bn.npy')
train_accuracy_cnn2_sigmoid_bn=np.load('save/train_accuracy_cnn2_sigmoid_bn.npy')
test_loss_cnn2_sigmoid_bn=np.load('save/test_loss_cnn2_sigmoid_bn.npy')
test_accuracy_cnn2_sigmoid_bn=np.load('save/test_accuracy_cnn2_sigmoid_bn.npy')

# %%
train_loss_cnn2_dp=np.load('save/train_loss_cnn2_dp.npy')
train_accuracy_cnn2_dp=np.load('save/train_accuracy_cnn2_dp.npy')
test_loss_cnn2_dp=np.load('save/test_loss_cnn2_dp.npy')
test_accuracy_cnn2_dp=np.load('save/test_accuracy_cnn2_dp.npy')

# %%
train_loss_deep_res=np.load('save/train_loss_deep_res.npy')
train_accuracy_deep_res=np.load('save/train_accuracy_deep_res.npy')
test_loss_deep_res=np.load('save/test_loss_deep_res.npy')
test_accuracy_deep_res=np.load('save/test_accuracy_mlp3.npy')

# %%
plot_different_histories(train_loss_cnn2,train_accuracy_cnn2, test_loss_cnn2,test_accuracy_cnn2,
                             train_loss_cnn2_dp,train_accuracy_cnn2_dp,test_loss_cnn2_dp,test_accuracy_cnn2_dp,
                             train_loss_cnn2_bn,train_accuracy_cnn2_bn, test_loss_cnn2_bn,test_accuracy_cnn2_bn,
                             train_loss_cnn2_sigmoid_bn,train_accuracy_cnn2_sigmoid_bn,test_loss_cnn2_sigmoid_bn,test_accuracy_cnn2_sigmoid_bn,
                             train_loss_list_5=train_loss_deep_res,train_accuracy_list_5=train_accuracy_deep_res, 
                             test_loss_list_5=test_loss_deep_res,test_accuracy_list_5=test_accuracy_deep_res,
                             label_1='Original CNN', label_2='CNN with Dropout', label_3='CNN with Batch Normalization', 
                             label_4='CNN with Sigmoid and Batch Normalization', label_5='Deeper CNN with Residual Block',
                             title='Learning Curves of Original CNN and CNN with Tricks')

# %% [markdown]
# # 5. Combination with Features from Digit Class : Weight Sharing

# %%
class ConvNet_WS(nn.Module):
    def __init__(self ):
        super(ConvNet_WS, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3,padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.conv3 = nn.Conv2d(16, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*6*6 ,64)
        self.fc2 = nn.Linear(64, 10)
        self.fc3 = nn.Linear(128, 16)
        self.fc4 = nn.Linear(16, 2)
        #self.fc5  = nn.Linear(64,2)
        self.bn8 = torch.nn.BatchNorm2d(8)
        self.bn16 = torch.nn.BatchNorm2d(16)
        
        
    def subforward(self,temp_x):
        temp_x=self.conv1(temp_x)
        temp_x=F.relu(temp_x) 
        #temp_x=self.bn8(temp_x)
        temp_x=self.conv2(temp_x)
        temp_x=F.relu(temp_x)
        #temp_x=self.bn16(temp_x)
        temp_x=F.max_pool2d(temp_x, kernel_size=2, stride=2)
        #temp_x=self.conv3(temp_x)
        #temp_x=self.bn16(temp_x)
        #temp_x=F.relu(temp_x)
        temp_x=temp_x.view(temp_x.size(0),-1)
        temp_x=self.fc1(temp_x)
        temp_x=F.relu(temp_x)
        x=temp_x   
        temp_x=self.fc2(temp_x)
        return temp_x, x
        
    def forward(self, x):
        x1=x[:,0,:,:].view(x.size(0),1,14,14)
        x2=x[:,1,:,:].view(x.size(0),1,14,14)
        
        temp_x1,new_x1=self.subforward(x1)
        temp_x2,new_x2=self.subforward(x2)
        new_x=torch.cat((new_x1.view(-1,64), new_x2.view(-1, 64)), 1)
        new_x=F.relu(self.fc3(new_x))
        new_x=self.fc4(new_x)
        #new_x=self.fc5(new_x)
        
        
        
        
        return temp_x1,temp_x2,new_x

# %%
def train_model_WS(model , optim='sgd', if_auxiliary_loss=False,auxiliary_loss_ratio=1,
                train_input=train_input, train_target=train_target, train_class=train_class,
                test_input=test_input, test_target=test_target, test_class=test_class,
                epochs=50, batch_size=100, learning_rate=1e-3,
                 if_print=False):
    criterion = nn.CrossEntropyLoss()
    if optim=='sgd':
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate)
    elif optim=='adm':
        optimizer = torch.optim.ADAM(model.parameters(),lr=learning_rate)
    train_loss_list=train_accuracy_list=[]
    valid_loss_list=valid_accuracy_list=[]
    test_loss_list=test_accuracy_list=[]
    for e in range(epochs):
        for b in range(0, train_input.size(0), batch_size):
            temp_train_input=train_input.narrow(0, b, batch_size)    
            temp_train_target=train_target.narrow(0, b, batch_size)
            temp_train_class=train_class.narrow(0, b, batch_size)
            x1_output,x2_output,train_output = model(temp_train_input)
            loss = criterion(train_output, temp_train_target)
            auxiliary_loss_1 = criterion(x1_output, temp_train_class[:,0])      
            auxiliary_loss_2 = criterion(x2_output, temp_train_class[:,1]) 
            auxiliary_loss=auxiliary_loss_1+auxiliary_loss_ratio*auxiliary_loss_2
            if if_auxiliary_loss:
                temp_weight=(epochs-e)/epochs
                loss=loss+auxiliary_loss*auxiliary_loss_ratio*temp_weight
                
            model.zero_grad()
            loss.backward()
            optimizer.step()
                
        _,_,train_temp_output = model(train_input)
        train_temp_loss = criterion(train_temp_output, train_target)
        _, temp_train_pred =torch.max(F.softmax(train_temp_output).data, 1)
        train_temp_accuracy=((temp_train_pred == train_target).sum().item())/train_input.size(0)
        
        _,_,test_temp_output=model(test_input)
        test_temp_loss = criterion(test_temp_output, test_target)
        _, temp_test_pred =torch.max(F.softmax(test_temp_output).data, 1)
        test_temp_accuracy=((temp_test_pred == test_target).sum().item())/test_input.size(0)
        
        train_loss_list=train_loss_list+[train_temp_loss]
        train_accuracy_list=train_accuracy_list+[train_temp_accuracy]
        test_loss_list=test_loss_list+[test_temp_loss]
        test_accuracy_list=test_accuracy_list+[test_temp_accuracy]
        
        if if_print:
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Training Loss: {:.4f}..".format(train_temp_loss),
                  "Training Accuracy: {:.4f}..".format(train_temp_accuracy), 
                  "Validation Loss: {:.4f}..".format(test_temp_loss),
                  "Validation Accuracy: {:.4f}..".format(test_temp_accuracy),  )
                

    return model, train_loss_list,train_accuracy_list, test_loss_list,test_accuracy_list

# %% [markdown]
# ### 5.1 Weight without Auxiliary Loss

# %%
model_ws=ConvNet_WS()
model_ws.apply(weights_init)
model_ws,train_loss_ws,train_accuracy_ws, test_loss_ws,test_accuracy_ws=\
                                  train_model_WS(model_ws, if_auxiliary_loss=False,epochs=50,if_print=True)
evaluate_result(train_loss_ws,train_accuracy_ws, test_loss_ws,test_accuracy_ws,\
                'Learning Curve of Second ConvNet with Weight Sharing')
# Out:
# Epoch: 1/50.. Training Loss: 0.7242.. Training Accuracy: 0.4870.. Validation Loss: 0.7398.. Validation Accuracy: 0.4420..
# Epoch: 2/50.. Training Loss: 0.7063.. Training Accuracy: 0.5210.. Validation Loss: 0.7243.. Validation Accuracy: 0.4740..
# Epoch: 3/50.. Training Loss: 0.6939.. Training Accuracy: 0.5480.. Validation Loss: 0.7125.. Validation Accuracy: 0.4970..
# Epoch: 4/50.. Training Loss: 0.6836.. Training Accuracy: 0.5820.. Validation Loss: 0.7030.. Validation Accuracy: 0.5220..
# Epoch: 5/50.. Training Loss: 0.6747.. Training Accuracy: 0.5980.. Validation Loss: 0.6950.. Validation Accuracy: 0.5360..
# Epoch: 6/50.. Training Loss: 0.6666.. Training Accuracy: 0.6100.. Validation Loss: 0.6878.. Validation Accuracy: 0.5530..
# Epoch: 7/50.. Training Loss: 0.6590.. Training Accuracy: 0.6170.. Validation Loss: 0.6810.. Validation Accuracy: 0.5660..
# Epoch: 8/50.. Training Loss: 0.6517.. Training Accuracy: 0.6310.. Validation Loss: 0.6744.. Validation Accuracy: 0.5810..
# Epoch: 9/50.. Training Loss: 0.6444.. Training Accuracy: 0.6380.. Validation Loss: 0.6680.. Validation Accuracy: 0.5820..
# Epoch: 10/50.. Training Loss: 0.6372.. Training Accuracy: 0.6480.. Validation Loss: 0.6617.. Validation Accuracy: 0.5920..
# Epoch: 11/50.. Training Loss: 0.6298.. Training Accuracy: 0.6610.. Validation Loss: 0.6553.. Validation Accuracy: 0.6020..
# Epoch: 12/50.. Training Loss: 0.6225.. Training Accuracy: 0.6710.. Validation Loss: 0.6490.. Validation Accuracy: 0.6190..
# Epoch: 13/50.. Training Loss: 0.6150.. Training Accuracy: 0.6840.. Validation Loss: 0.6426.. Validation Accuracy: 0.6300..
# Epoch: 14/50.. Training Loss: 0.6073.. Training Accuracy: 0.6850.. Validation Loss: 0.6360.. Validation Accuracy: 0.6380..
# Epoch: 15/50.. Training Loss: 0.5994.. Training Accuracy: 0.6950.. Validation Loss: 0.6293.. Validation Accuracy: 0.6570..
# Epoch: 16/50.. Training Loss: 0.5914.. Training Accuracy: 0.7000.. Validation Loss: 0.6225.. Validation Accuracy: 0.6630..
# Epoch: 17/50.. Training Loss: 0.5835.. Training Accuracy: 0.7050.. Validation Loss: 0.6157.. Validation Accuracy: 0.6700..
# Epoch: 18/50.. Training Loss: 0.5755.. Training Accuracy: 0.7180.. Validation Loss: 0.6089.. Validation Accuracy: 0.6820..
# Epoch: 19/50.. Training Loss: 0.5673.. Training Accuracy: 0.7230.. Validation Loss: 0.6019.. Validation Accuracy: 0.6860..
# Epoch: 20/50.. Training Loss: 0.5592.. Training Accuracy: 0.7280.. Validation Loss: 0.5948.. Validation Accuracy: 0.6910..
# Epoch: 21/50.. Training Loss: 0.5510.. Training Accuracy: 0.7360.. Validation Loss: 0.5880.. Validation Accuracy: 0.6920..
# Epoch: 22/50.. Training Loss: 0.5429.. Training Accuracy: 0.7400.. Validation Loss: 0.5813.. Validation Accuracy: 0.6970..
# Epoch: 23/50.. Training Loss: 0.5349.. Training Accuracy: 0.7510.. Validation Loss: 0.5747.. Validation Accuracy: 0.7030..
# Epoch: 24/50.. Training Loss: 0.5270.. Training Accuracy: 0.7530.. Validation Loss: 0.5685.. Validation Accuracy: 0.7080..
# Epoch: 25/50.. Training Loss: 0.5192.. Training Accuracy: 0.7590.. Validation Loss: 0.5623.. Validation Accuracy: 0.7130..
# Epoch: 26/50.. Training Loss: 0.5115.. Training Accuracy: 0.7630.. Validation Loss: 0.5564.. Validation Accuracy: 0.7200..
# Epoch: 27/50.. Training Loss: 0.5040.. Training Accuracy: 0.7680.. Validation Loss: 0.5505.. Validation Accuracy: 0.7230..
# Epoch: 28/50.. Training Loss: 0.4965.. Training Accuracy: 0.7700.. Validation Loss: 0.5451.. Validation Accuracy: 0.7300..
# Epoch: 29/50.. Training Loss: 0.4890.. Training Accuracy: 0.7730.. Validation Loss: 0.5398.. Validation Accuracy: 0.7290..
# Epoch: 30/50.. Training Loss: 0.4817.. Training Accuracy: 0.7790.. Validation Loss: 0.5347.. Validation Accuracy: 0.7320..
# Epoch: 31/50.. Training Loss: 0.4743.. Training Accuracy: 0.7820.. Validation Loss: 0.5300.. Validation Accuracy: 0.7330..
# Epoch: 32/50.. Training Loss: 0.4675.. Training Accuracy: 0.7880.. Validation Loss: 0.5256.. Validation Accuracy: 0.7400..
# Epoch: 33/50.. Training Loss: 0.4607.. Training Accuracy: 0.7850.. Validation Loss: 0.5216.. Validation Accuracy: 0.7430..
# Epoch: 34/50.. Training Loss: 0.4542.. Training Accuracy: 0.7890.. Validation Loss: 0.5180.. Validation Accuracy: 0.7410..
# Epoch: 35/50.. Training Loss: 0.4480.. Training Accuracy: 0.7920.. Validation Loss: 0.5146.. Validation Accuracy: 0.7410..
# Epoch: 36/50.. Training Loss: 0.4421.. Training Accuracy: 0.7910.. Validation Loss: 0.5113.. Validation Accuracy: 0.7430..
# Epoch: 37/50.. Training Loss: 0.4364.. Training Accuracy: 0.7960.. Validation Loss: 0.5083.. Validation Accuracy: 0.7470..
# Epoch: 38/50.. Training Loss: 0.4309.. Training Accuracy: 0.7980.. Validation Loss: 0.5054.. Validation Accuracy: 0.7480..
# Epoch: 39/50.. Training Loss: 0.4257.. Training Accuracy: 0.7990.. Validation Loss: 0.5027.. Validation Accuracy: 0.7500..
# Epoch: 40/50.. Training Loss: 0.4205.. Training Accuracy: 0.8030.. Validation Loss: 0.5002.. Validation Accuracy: 0.7530..
# Epoch: 41/50.. Training Loss: 0.4155.. Training Accuracy: 0.8060.. Validation Loss: 0.4978.. Validation Accuracy: 0.7570..
# Epoch: 42/50.. Training Loss: 0.4106.. Training Accuracy: 0.8090.. Validation Loss: 0.4956.. Validation Accuracy: 0.7570..
# Epoch: 43/50.. Training Loss: 0.4058.. Training Accuracy: 0.8120.. Validation Loss: 0.4936.. Validation Accuracy: 0.7570..
# Epoch: 44/50.. Training Loss: 0.4011.. Training Accuracy: 0.8140.. Validation Loss: 0.4915.. Validation Accuracy: 0.7650..
# Epoch: 45/50.. Training Loss: 0.3965.. Training Accuracy: 0.8160.. Validation Loss: 0.4896.. Validation Accuracy: 0.7660..
# Epoch: 46/50.. Training Loss: 0.3921.. Training Accuracy: 0.8160.. Validation Loss: 0.4879.. Validation Accuracy: 0.7680..
# Epoch: 47/50.. Training Loss: 0.3878.. Training Accuracy: 0.8190.. Validation Loss: 0.4863.. Validation Accuracy: 0.7710..
# Epoch: 48/50.. Training Loss: 0.3836.. Training Accuracy: 0.8220.. Validation Loss: 0.4847.. Validation Accuracy: 0.7690..
# Epoch: 49/50.. Training Loss: 0.3796.. Training Accuracy: 0.8250.. Validation Loss: 0.4832.. Validation Accuracy: 0.7660..
# Epoch: 50/50.. Training Loss: 0.3756.. Training Accuracy: 0.8270.. Validation Loss: 0.4815.. Validation Accuracy: 0.7690..
# The Best Validation Accuracy is : 0.7710..

# %%
import numpy as np
np.save('save/test_accuracy_ws.npy',np.array(test_accuracy_ws ))
np.save('save/train_accuracy_ws.npy',np.array(train_accuracy_ws ))

# %% [markdown]
# ### 5.2 Weight with Auxiliary Loss

# %%
model_ws_al=ConvNet_WS()
model_ws_al.apply(weights_init)
model_ws_al,train_loss_ws_al,train_accuracy_ws_al, test_loss_ws_al,test_accuracy_ws_al=\
                                  train_model_WS(model_ws_al, if_auxiliary_loss=True,epochs=50,if_print=True,auxiliary_loss_ratio=5)
evaluate_result(train_loss_ws_al,train_accuracy_ws_al, test_loss_ws_al,test_accuracy_ws_al,\
                'Learning Curve of Second ConvNet with Weight Sharing and Auxiliart Loss')
# Out:
# Epoch: 1/50.. Training Loss: 0.6914.. Training Accuracy: 0.5220.. Validation Loss: 0.6910.. Validation Accuracy: 0.5370..
# Epoch: 2/50.. Training Loss: 0.6840.. Training Accuracy: 0.5420.. Validation Loss: 0.6804.. Validation Accuracy: 0.5600..
# Epoch: 3/50.. Training Loss: 0.6814.. Training Accuracy: 0.5560.. Validation Loss: 0.6760.. Validation Accuracy: 0.5730..
# Epoch: 4/50.. Training Loss: 0.6840.. Training Accuracy: 0.5470.. Validation Loss: 0.6790.. Validation Accuracy: 0.5690..
# Epoch: 5/50.. Training Loss: 0.6793.. Training Accuracy: 0.5560.. Validation Loss: 0.6733.. Validation Accuracy: 0.5820..
# Epoch: 6/50.. Training Loss: 0.6732.. Training Accuracy: 0.5850.. Validation Loss: 0.6694.. Validation Accuracy: 0.5940..
# Epoch: 7/50.. Training Loss: 0.6661.. Training Accuracy: 0.5940.. Validation Loss: 0.6633.. Validation Accuracy: 0.5950..
# Epoch: 8/50.. Training Loss: 0.6609.. Training Accuracy: 0.6070.. Validation Loss: 0.6580.. Validation Accuracy: 0.6010..
# Epoch: 9/50.. Training Loss: 0.6547.. Training Accuracy: 0.6160.. Validation Loss: 0.6535.. Validation Accuracy: 0.6160..
# Epoch: 10/50.. Training Loss: 0.6480.. Training Accuracy: 0.6280.. Validation Loss: 0.6472.. Validation Accuracy: 0.6290..
# Epoch: 11/50.. Training Loss: 0.6402.. Training Accuracy: 0.6380.. Validation Loss: 0.6402.. Validation Accuracy: 0.6420..
# Epoch: 12/50.. Training Loss: 0.6335.. Training Accuracy: 0.6380.. Validation Loss: 0.6339.. Validation Accuracy: 0.6490..
# Epoch: 13/50.. Training Loss: 0.6252.. Training Accuracy: 0.6480.. Validation Loss: 0.6268.. Validation Accuracy: 0.6610..
# Epoch: 14/50.. Training Loss: 0.6171.. Training Accuracy: 0.6590.. Validation Loss: 0.6192.. Validation Accuracy: 0.6640..
# Epoch: 15/50.. Training Loss: 0.6082.. Training Accuracy: 0.6730.. Validation Loss: 0.6113.. Validation Accuracy: 0.6790..
# Epoch: 16/50.. Training Loss: 0.5989.. Training Accuracy: 0.6800.. Validation Loss: 0.6031.. Validation Accuracy: 0.6880..
# Epoch: 17/50.. Training Loss: 0.5893.. Training Accuracy: 0.6940.. Validation Loss: 0.5950.. Validation Accuracy: 0.7050..
# Epoch: 18/50.. Training Loss: 0.5793.. Training Accuracy: 0.7050.. Validation Loss: 0.5863.. Validation Accuracy: 0.7060..
# Epoch: 19/50.. Training Loss: 0.5693.. Training Accuracy: 0.7110.. Validation Loss: 0.5777.. Validation Accuracy: 0.7180..
# Epoch: 20/50.. Training Loss: 0.5591.. Training Accuracy: 0.7230.. Validation Loss: 0.5688.. Validation Accuracy: 0.7240..
# Epoch: 21/50.. Training Loss: 0.5491.. Training Accuracy: 0.7300.. Validation Loss: 0.5598.. Validation Accuracy: 0.7270..
# Epoch: 22/50.. Training Loss: 0.5389.. Training Accuracy: 0.7380.. Validation Loss: 0.5509.. Validation Accuracy: 0.7310..
# Epoch: 23/50.. Training Loss: 0.5290.. Training Accuracy: 0.7430.. Validation Loss: 0.5424.. Validation Accuracy: 0.7420..
# Epoch: 24/50.. Training Loss: 0.5192.. Training Accuracy: 0.7480.. Validation Loss: 0.5337.. Validation Accuracy: 0.7400..
# Epoch: 25/50.. Training Loss: 0.5095.. Training Accuracy: 0.7530.. Validation Loss: 0.5254.. Validation Accuracy: 0.7430..
# Epoch: 26/50.. Training Loss: 0.4999.. Training Accuracy: 0.7560.. Validation Loss: 0.5173.. Validation Accuracy: 0.7490..
# Epoch: 27/50.. Training Loss: 0.4907.. Training Accuracy: 0.7610.. Validation Loss: 0.5093.. Validation Accuracy: 0.7590..
# Epoch: 28/50.. Training Loss: 0.4814.. Training Accuracy: 0.7650.. Validation Loss: 0.5018.. Validation Accuracy: 0.7640..
# Epoch: 29/50.. Training Loss: 0.4726.. Training Accuracy: 0.7700.. Validation Loss: 0.4945.. Validation Accuracy: 0.7700..
# Epoch: 30/50.. Training Loss: 0.4641.. Training Accuracy: 0.7750.. Validation Loss: 0.4876.. Validation Accuracy: 0.7740..
# Epoch: 31/50.. Training Loss: 0.4559.. Training Accuracy: 0.7830.. Validation Loss: 0.4812.. Validation Accuracy: 0.7830..
# Epoch: 32/50.. Training Loss: 0.4481.. Training Accuracy: 0.7880.. Validation Loss: 0.4751.. Validation Accuracy: 0.7830..
# Epoch: 33/50.. Training Loss: 0.4406.. Training Accuracy: 0.7910.. Validation Loss: 0.4694.. Validation Accuracy: 0.7850..
# Epoch: 34/50.. Training Loss: 0.4333.. Training Accuracy: 0.7940.. Validation Loss: 0.4638.. Validation Accuracy: 0.7900..
# Epoch: 35/50.. Training Loss: 0.4262.. Training Accuracy: 0.7980.. Validation Loss: 0.4586.. Validation Accuracy: 0.7910..
# Epoch: 36/50.. Training Loss: 0.4194.. Training Accuracy: 0.8000.. Validation Loss: 0.4537.. Validation Accuracy: 0.7940..
# Epoch: 37/50.. Training Loss: 0.4129.. Training Accuracy: 0.8030.. Validation Loss: 0.4490.. Validation Accuracy: 0.7950..
# Epoch: 38/50.. Training Loss: 0.4066.. Training Accuracy: 0.8070.. Validation Loss: 0.4446.. Validation Accuracy: 0.8010..
# Epoch: 39/50.. Training Loss: 0.4007.. Training Accuracy: 0.8090.. Validation Loss: 0.4404.. Validation Accuracy: 0.8030..
# Epoch: 40/50.. Training Loss: 0.3949.. Training Accuracy: 0.8150.. Validation Loss: 0.4365.. Validation Accuracy: 0.8040..
# Epoch: 41/50.. Training Loss: 0.3893.. Training Accuracy: 0.8170.. Validation Loss: 0.4328.. Validation Accuracy: 0.8090..
# Epoch: 42/50.. Training Loss: 0.3838.. Training Accuracy: 0.8180.. Validation Loss: 0.4292.. Validation Accuracy: 0.8100..
# Epoch: 43/50.. Training Loss: 0.3784.. Training Accuracy: 0.8220.. Validation Loss: 0.4259.. Validation Accuracy: 0.8130..
# Epoch: 44/50.. Training Loss: 0.3731.. Training Accuracy: 0.8250.. Validation Loss: 0.4227.. Validation Accuracy: 0.8160..
# Epoch: 45/50.. Training Loss: 0.3679.. Training Accuracy: 0.8320.. Validation Loss: 0.4196.. Validation Accuracy: 0.8180..
# Epoch: 46/50.. Training Loss: 0.3630.. Training Accuracy: 0.8340.. Validation Loss: 0.4167.. Validation Accuracy: 0.8180..
# Epoch: 47/50.. Training Loss: 0.3582.. Training Accuracy: 0.8370.. Validation Loss: 0.4140.. Validation Accuracy: 0.8210..
# Epoch: 48/50.. Training Loss: 0.3536.. Training Accuracy: 0.8390.. Validation Loss: 0.4114.. Validation Accuracy: 0.8220..
# Epoch: 49/50.. Training Loss: 0.3491.. Training Accuracy: 0.8410.. Validation Loss: 0.4089.. Validation Accuracy: 0.8230..
# Epoch: 50/50.. Training Loss: 0.3448.. Training Accuracy: 0.8410.. Validation Loss: 0.4067.. Validation Accuracy: 0.8240..
# The Best Validation Accuracy is : 0.8240..

# %%
import numpy as np
np.save('save/test_accuracy_ws_al.npy',np.array(test_accuracy_ws_al ))
np.save('save/train_accuracy_ws_al.npy',np.array(train_accuracy_ws_al ))

# %% [markdown]
# # 6. Do the Binary Classification Directly by Digit Classification

# %%
class CNN_digit(nn.Module):
    def __init__(self, bn=False, dropout=0, activation='relu' ):
        super(CNN_digit, self).__init__()
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3,padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3)
        self.fc1 = nn.Linear(16*6*6 ,64)
        self.fc2 = nn.Linear(64, 10)
        self.bn8 = torch.nn.BatchNorm2d(8)
        self.bn16 = torch.nn.BatchNorm2d(16)
        self.bn32 = torch.nn.BatchNorm2d(32)
        self.bn=bn
        self.activation=activation
        self.dropout=dropout
    def forward(self, x):
        x=x.view(x.size(0),1,14,14)
        x=self.conv1(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
            
        if self.bn:
            x=self.bn8(x)
            
        x=self.conv2(x)
        if self.activation=='sigmoid':
            x=F.sigmoid(x)
        else:
            x=F.relu(x)
        if self.bn:
            x=self.bn16(x)
        
        x = F.dropout(x, p=self.dropout,training=self.training)
         
        x=F.max_pool2d(x, kernel_size=2, stride=2)
        
        
        
        
        x=x.view(x.size(0),-1)
        x=self.fc1(x)
        x=F.relu(x)
        x = self.fc2(x)
    
        return x
    
    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
def train_by_digit(model , optim='sgd',
                train_input=train_input, train_class=train_class, train_target=train_target,
                test_input=test_input, test_class=test_class, test_target=test_target,
                epochs=50, batch_size=100, learning_rate=1e-3, momentum=0,
                 if_print=False):
    criterion = nn.CrossEntropyLoss()
    if optim=='sgd':
        optimizer = torch.optim.SGD(model.parameters(),lr=learning_rate,momentum=momentum)
    elif optim=='adm':
        optimizer = torch.optim.ADAM(model.parameters(),lr=learning_rate)
    test_accuracy_list=train_accuracy_list=[]
    digit_train_accuracy_list=digit_test_accuracy_list=[]
    digit_train_loss_list=digit_test_loss_list=[]
    
    for e in range(epochs):
        for b in range(0, train_input.size(0), batch_size):
            temp_train_input=train_input.narrow(0, b, batch_size)    
            temp_train_class=train_class.narrow(0, b, batch_size)
            train_output_1 = model(temp_train_input[:,0,:,:])
            train_output_2 = model(temp_train_input[:,1,:,:])
            loss = criterion(train_output_1, temp_train_class[:,0])+criterion(train_output_2, temp_train_class[:,1])
            model.zero_grad()
            loss.backward()
            optimizer.step()
                
        train_temp_output_1 = model(train_input[:,0,:,:])
        train_temp_output_2 = model(train_input[:,1,:,:])
        _, temp_train_pred_1 =torch.max(F.softmax(train_temp_output_1).data, 1)
        _, temp_train_pred_2 =torch.max(F.softmax(train_temp_output_2).data, 1)
        train_temp_output=temp_train_pred_1<=temp_train_pred_2

        
        train_temp_accuracy=((train_temp_output.int() == train_target.int()).sum().item())/train_input.size(0)
        train_digit_accracy_1=(temp_train_pred_1.int()==train_class[:,0].int()).sum().item()/train_input.size(0)
        train_digit_accracy_2=(temp_train_pred_2.int()==train_class[:,1].int()).sum().item()/train_input.size(0)
        train_digit_accracy=(train_digit_accracy_1+train_digit_accracy_2)/2
        digit_train_accuracy_list=digit_train_accuracy_list+[train_digit_accracy]
        train_digit_loss = criterion(train_temp_output_1, train_class[:,0])+criterion(train_temp_output_2, train_class[:,1])
        digit_train_loss_list=digit_train_loss_list+[train_digit_loss]
 
        
        test_temp_output_1 = model(test_input[:,0,:,:])
        test_temp_output_2 = model(test_input[:,1,:,:])
        _, temp_test_pred_1 =torch.max(F.softmax(test_temp_output_1).data, 1)
        _, temp_test_pred_2 =torch.max(F.softmax(test_temp_output_2).data, 1)
        test_pred_output=temp_test_pred_1<=temp_test_pred_2
        test_digit_loss = criterion(test_temp_output_1, test_class[:,0])+criterion(test_temp_output_2, test_class[:,1])
        digit_test_loss_list=digit_test_loss_list+[test_digit_loss]
        

        test_temp_accuracy=((test_pred_output.int() == test_target.int()).sum().item())/test_input.size(0)
        test_digit_accracy=((temp_test_pred_1.int()==test_class[:,0].int()).sum().item()+(temp_test_pred_2.int()==test_class[:,1].int()).sum().item())/(2*test_input.size(0))
        digit_test_accuracy_list=digit_test_accuracy_list+[test_digit_accracy]
        
        
        train_accuracy_list=train_accuracy_list+[train_temp_accuracy]
        test_accuracy_list=test_accuracy_list+[test_temp_accuracy]
        
        if if_print:
            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Digit Training Loss: {:.4f}..".format(train_digit_loss),
                  "Digit Training Accuracy: {:.4f}..".format(train_digit_accracy),

                  "Boolea n Training Accuracy: {:.4f}..".format(train_temp_accuracy),
                  
                  "Digit Validation Loss: {:.4f}..".format(test_digit_loss),
                  "Digit Validation Accuracy: {:.4f}..".format(test_digit_accracy),

                  "Boolean Validation Accuracy: {:.4f}..".format(test_temp_accuracy)  )
                

    return model, digit_train_loss_list,digit_train_accuracy_list, train_accuracy_list,digit_test_loss_list,digit_test_accuracy_list,test_accuracy_list

# %%
model_digit=CNN_digit()
model_digit.apply(weights_init)
model_digit,digit_train_loss,digit_train_accuracy,_, digit_test_loss,digit_test_accuracy,_=\
                                                train_by_digit(model_digit,if_print=True, learning_rate=0.01)
evaluate_result(digit_train_loss,digit_train_accuracy, digit_test_loss,digit_test_accuracy,
                'Learning Curve of Digit Classification by CNN Trained Directly on Digit Class')
# Out:
# Epoch: 1/50.. Digit Training Loss: 4.4124.. Digit Training Accuracy: 0.2480.. Boolea n Training Accuracy: 0.5890.. Digit Validation Loss: 4.4135.. Digit Validation Accuracy: 0.2385.. Boolean Validation Accuracy: 0.5540..
# Epoch: 2/50.. Digit Training Loss: 3.0493.. Digit Training Accuracy: 0.5555.. Boolea n Training Accuracy: 0.7000.. Digit Validation Loss: 3.1015.. Digit Validation Accuracy: 0.5385.. Boolean Validation Accuracy: 0.7080..
# Epoch: 3/50.. Digit Training Loss: 2.1532.. Digit Training Accuracy: 0.6430.. Boolea n Training Accuracy: 0.7760.. Digit Validation Loss: 2.1825.. Digit Validation Accuracy: 0.6445.. Boolean Validation Accuracy: 0.7960..
# Epoch: 4/50.. Digit Training Loss: 0.9684.. Digit Training Accuracy: 0.8500.. Boolea n Training Accuracy: 0.9010.. Digit Validation Loss: 1.0715.. Digit Validation Accuracy: 0.8240.. Boolean Validation Accuracy: 0.8910..
# Epoch: 5/50.. Digit Training Loss: 0.7369.. Digit Training Accuracy: 0.8885.. Boolea n Training Accuracy: 0.9220.. Digit Validation Loss: 0.8837.. Digit Validation Accuracy: 0.8605.. Boolean Validation Accuracy: 0.9100..
# Epoch: 6/50.. Digit Training Loss: 0.5988.. Digit Training Accuracy: 0.9065.. Boolea n Training Accuracy: 0.9330.. Digit Validation Loss: 0.7880.. Digit Validation Accuracy: 0.8750.. Boolean Validation Accuracy: 0.9140..
# Epoch: 7/50.. Digit Training Loss: 0.5014.. Digit Training Accuracy: 0.9200.. Boolea n Training Accuracy: 0.9430.. Digit Validation Loss: 0.7226.. Digit Validation Accuracy: 0.8915.. Boolean Validation Accuracy: 0.9280..
# Epoch: 8/50.. Digit Training Loss: 0.4416.. Digit Training Accuracy: 0.9290.. Boolea n Training Accuracy: 0.9510.. Digit Validation Loss: 0.6905.. Digit Validation Accuracy: 0.8930.. Boolean Validation Accuracy: 0.9240..
# Epoch: 9/50.. Digit Training Loss: 0.3532.. Digit Training Accuracy: 0.9480.. Boolea n Training Accuracy: 0.9630.. Digit Validation Loss: 0.6173.. Digit Validation Accuracy: 0.9045.. Boolean Validation Accuracy: 0.9300..
# Epoch: 10/50.. Digit Training Loss: 0.2979.. Digit Training Accuracy: 0.9575.. Boolea n Training Accuracy: 0.9700.. Digit Validation Loss: 0.5724.. Digit Validation Accuracy: 0.9115.. Boolean Validation Accuracy: 0.9350..
# Epoch: 11/50.. Digit Training Loss: 0.2649.. Digit Training Accuracy: 0.9620.. Boolea n Training Accuracy: 0.9760.. Digit Validation Loss: 0.5546.. Digit Validation Accuracy: 0.9160.. Boolean Validation Accuracy: 0.9380..
# Epoch: 12/50.. Digit Training Loss: 0.2275.. Digit Training Accuracy: 0.9660.. Boolea n Training Accuracy: 0.9780.. Digit Validation Loss: 0.5256.. Digit Validation Accuracy: 0.9215.. Boolean Validation Accuracy: 0.9410..
# Epoch: 13/50.. Digit Training Loss: 0.1954.. Digit Training Accuracy: 0.9725.. Boolea n Training Accuracy: 0.9840.. Digit Validation Loss: 0.5040.. Digit Validation Accuracy: 0.9225.. Boolean Validation Accuracy: 0.9400..
# Epoch: 14/50.. Digit Training Loss: 0.1685.. Digit Training Accuracy: 0.9770.. Boolea n Training Accuracy: 0.9870.. Digit Validation Loss: 0.4897.. Digit Validation Accuracy: 0.9255.. Boolean Validation Accuracy: 0.9440..
# Epoch: 15/50.. Digit Training Loss: 0.1444.. Digit Training Accuracy: 0.9800.. Boolea n Training Accuracy: 0.9870.. Digit Validation Loss: 0.4715.. Digit Validation Accuracy: 0.9275.. Boolean Validation Accuracy: 0.9470..
# Epoch: 16/50.. Digit Training Loss: 0.1280.. Digit Training Accuracy: 0.9815.. Boolea n Training Accuracy: 0.9880.. Digit Validation Loss: 0.4677.. Digit Validation Accuracy: 0.9285.. Boolean Validation Accuracy: 0.9500..
# Epoch: 17/50.. Digit Training Loss: 0.1119.. Digit Training Accuracy: 0.9825.. Boolea n Training Accuracy: 0.9890.. Digit Validation Loss: 0.4645.. Digit Validation Accuracy: 0.9290.. Boolean Validation Accuracy: 0.9480..
# Epoch: 18/50.. Digit Training Loss: 0.0989.. Digit Training Accuracy: 0.9865.. Boolea n Training Accuracy: 0.9940.. Digit Validation Loss: 0.4629.. Digit Validation Accuracy: 0.9310.. Boolean Validation Accuracy: 0.9510..
# Epoch: 19/50.. Digit Training Loss: 0.0885.. Digit Training Accuracy: 0.9905.. Boolea n Training Accuracy: 0.9960.. Digit Validation Loss: 0.4645.. Digit Validation Accuracy: 0.9315.. Boolean Validation Accuracy: 0.9520..
# Epoch: 20/50.. Digit Training Loss: 0.0782.. Digit Training Accuracy: 0.9925.. Boolea n Training Accuracy: 0.9960.. Digit Validation Loss: 0.4668.. Digit Validation Accuracy: 0.9310.. Boolean Validation Accuracy: 0.9500..
# Epoch: 21/50.. Digit Training Loss: 0.0699.. Digit Training Accuracy: 0.9925.. Boolea n Training Accuracy: 0.9960.. Digit Validation Loss: 0.4710.. Digit Validation Accuracy: 0.9325.. Boolean Validation Accuracy: 0.9530..
# Epoch: 22/50.. Digit Training Loss: 0.0637.. Digit Training Accuracy: 0.9930.. Boolea n Training Accuracy: 0.9960.. Digit Validation Loss: 0.4750.. Digit Validation Accuracy: 0.9330.. Boolean Validation Accuracy: 0.9540..
# Epoch: 23/50.. Digit Training Loss: 0.0575.. Digit Training Accuracy: 0.9940.. Boolea n Training Accuracy: 0.9960.. Digit Validation Loss: 0.4782.. Digit Validation Accuracy: 0.9340.. Boolean Validation Accuracy: 0.9560..
# Epoch: 24/50.. Digit Training Loss: 0.0526.. Digit Training Accuracy: 0.9945.. Boolea n Training Accuracy: 0.9970.. Digit Validation Loss: 0.4831.. Digit Validation Accuracy: 0.9340.. Boolean Validation Accuracy: 0.9540..
# Epoch: 25/50.. Digit Training Loss: 0.0480.. Digit Training Accuracy: 0.9950.. Boolea n Training Accuracy: 0.9980.. Digit Validation Loss: 0.4861.. Digit Validation Accuracy: 0.9340.. Boolean Validation Accuracy: 0.9540..
# Epoch: 26/50.. Digit Training Loss: 0.0443.. Digit Training Accuracy: 0.9960.. Boolea n Training Accuracy: 0.9980.. Digit Validation Loss: 0.4926.. Digit Validation Accuracy: 0.9340.. Boolean Validation Accuracy: 0.9540..
# Epoch: 27/50.. Digit Training Loss: 0.0408.. Digit Training Accuracy: 0.9965.. Boolea n Training Accuracy: 0.9980.. Digit Validation Loss: 0.4970.. Digit Validation Accuracy: 0.9335.. Boolean Validation Accuracy: 0.9540..
# Epoch: 28/50.. Digit Training Loss: 0.0378.. Digit Training Accuracy: 0.9965.. Boolea n Training Accuracy: 0.9990.. Digit Validation Loss: 0.5014.. Digit Validation Accuracy: 0.9340.. Boolean Validation Accuracy: 0.9540..
# Epoch: 29/50.. Digit Training Loss: 0.0348.. Digit Training Accuracy: 0.9975.. Boolea n Training Accuracy: 0.9990.. Digit Validation Loss: 0.5052.. Digit Validation Accuracy: 0.9350.. Boolean Validation Accuracy: 0.9560..
# Epoch: 30/50.. Digit Training Loss: 0.0326.. Digit Training Accuracy: 0.9975.. Boolea n Training Accuracy: 0.9990.. Digit Validation Loss: 0.5095.. Digit Validation Accuracy: 0.9350.. Boolean Validation Accuracy: 0.9550..
# Epoch: 31/50.. Digit Training Loss: 0.0304.. Digit Training Accuracy: 0.9975.. Boolea n Training Accuracy: 0.9990.. Digit Validation Loss: 0.5137.. Digit Validation Accuracy: 0.9350.. Boolean Validation Accuracy: 0.9550..
# Epoch: 32/50.. Digit Training Loss: 0.0283.. Digit Training Accuracy: 0.9980.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5180.. Digit Validation Accuracy: 0.9345.. Boolean Validation Accuracy: 0.9540..
# Epoch: 33/50.. Digit Training Loss: 0.0265.. Digit Training Accuracy: 0.9980.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5215.. Digit Validation Accuracy: 0.9345.. Boolean Validation Accuracy: 0.9540..
# Epoch: 34/50.. Digit Training Loss: 0.0248.. Digit Training Accuracy: 0.9975.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5263.. Digit Validation Accuracy: 0.9345.. Boolean Validation Accuracy: 0.9530..
# Epoch: 35/50.. Digit Training Loss: 0.0234.. Digit Training Accuracy: 0.9980.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5302.. Digit Validation Accuracy: 0.9350.. Boolean Validation Accuracy: 0.9540..
# Epoch: 36/50.. Digit Training Loss: 0.0220.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5342.. Digit Validation Accuracy: 0.9350.. Boolean Validation Accuracy: 0.9530..
# Epoch: 37/50.. Digit Training Loss: 0.0204.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5370.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9520..
# Epoch: 38/50.. Digit Training Loss: 0.0194.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5412.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9520..
# Epoch: 39/50.. Digit Training Loss: 0.0181.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5431.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9530..
# Epoch: 40/50.. Digit Training Loss: 0.0172.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5471.. Digit Validation Accuracy: 0.9365.. Boolean Validation Accuracy: 0.9530..
# Epoch: 41/50.. Digit Training Loss: 0.0162.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5491.. Digit Validation Accuracy: 0.9370.. Boolean Validation Accuracy: 0.9530..
# Epoch: 42/50.. Digit Training Loss: 0.0152.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5519.. Digit Validation Accuracy: 0.9365.. Boolean Validation Accuracy: 0.9530..
# Epoch: 43/50.. Digit Training Loss: 0.0144.. Digit Training Accuracy: 0.9985.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5543.. Digit Validation Accuracy: 0.9375.. Boolean Validation Accuracy: 0.9530..
# Epoch: 44/50.. Digit Training Loss: 0.0136.. Digit Training Accuracy: 0.9990.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5570.. Digit Validation Accuracy: 0.9365.. Boolean Validation Accuracy: 0.9510..
# Epoch: 45/50.. Digit Training Loss: 0.0128.. Digit Training Accuracy: 0.9990.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5588.. Digit Validation Accuracy: 0.9375.. Boolean Validation Accuracy: 0.9520..
# Epoch: 46/50.. Digit Training Loss: 0.0122.. Digit Training Accuracy: 0.9990.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5616.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9500..
# Epoch: 47/50.. Digit Training Loss: 0.0115.. Digit Training Accuracy: 0.9995.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5638.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9500..
# Epoch: 48/50.. Digit Training Loss: 0.0109.. Digit Training Accuracy: 0.9995.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5659.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9500..
# Epoch: 49/50.. Digit Training Loss: 0.0103.. Digit Training Accuracy: 0.9995.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5677.. Digit Validation Accuracy: 0.9360.. Boolean Validation Accuracy: 0.9500..
# Epoch: 50/50.. Digit Training Loss: 0.0098.. Digit Training Accuracy: 0.9995.. Boolea n Training Accuracy: 1.0000.. Digit Validation Loss: 0.5695.. Digit Validation Accuracy: 0.9365.. Boolean Validation Accuracy: 0.9500..
# The Best Validation Accuracy is : 0.9375..

# %%
model_digit=CNN_digit()
model_digit.apply(weights_init)
_,_,_,train_accuracy_from_digit,_,_,test_accuracy_from_digit=train_by_digit(model_digit,if_print=False, learning_rate=0.01)
print('Best Validation Accuracy of Boolean Classification from CNN Trained Directly on Digit Class: '+str(max(test_accuracy_from_digit)))
# Out:
# Best Validation Accuracy of Boolean Classification from CNN Trained Directly on Digit Class: 0.95

# %%
import numpy as np
np.save('save/train_accuracy_from_digit.npy',np.array(train_accuracy_from_digit ))
np.save('save/test_accuracy_from_digit.npy',np.array(test_accuracy_from_digit ))

# %% [markdown]
# # Comparison of Combinations of CNN Models and Features from Digit Class

# %%
train_accuracy_ws=np.load('save/train_accuracy_ws.npy')
test_accuracy_ws=np.load('save/test_accuracy_ws.npy')

# %%
train_accuracy_ws_al=np.load('save/train_accuracy_ws_al.npy')
test_accuracy_ws_al=np.load('save/test_accuracy_ws_al.npy')

# %%
train_accuracy_from_digit=np.load('save/train_accuracy_from_digit.npy')
test_accuracy_from_digit=np.load('save/test_accuracy_from_digit.npy')

# %%
plot_different_histories(None,train_accuracy_cnn2_bn,None,test_accuracy_cnn2_bn,
                             None,train_accuracy_ws, None,test_accuracy_ws,
                             None,train_accuracy_ws_al,None,test_accuracy_ws_al,
                             None,train_accuracy_from_digit, None,test_accuracy_from_digit,
                             
                             label_1='Best Simple CNN', label_2='CNN with Weight Sharing', label_3='CNN with Weight Sharing and Auxiliary', 
                             label_4='CNN Trained Directly on Digit Class',
                             title='Learning Curves of Combinations of CNN Models and Features from Digit Class')
